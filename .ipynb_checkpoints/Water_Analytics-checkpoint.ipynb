# %%
import pandas as pd
import numpy as np
import json as js
from datetime import datetime
from dateutil.relativedelta import relativedelta

#read in csv and/or dataset
water_df = pd.read_csv('../SourceMaterial/Measures/water_temps.csv')
ph_df = pd.read_csv('../SourceMaterial/Measures/ph.csv')
conductivity_df = pd.read_csv('../SourceMaterial/Measures/conductivity.csv')
water_df = water_df.dropna()
ph_df = ph_df.dropna()
conductivity_df = conductivity_df.dropna()
#order by HUC then Date
water_df.sort_values(by=['HUCNAME_', 'Date'])
# water_df.set_index('HUCNAME_')
# variables = water_df.columns().drop('HUCNAME_')
hucs = water_df['HUCNAME_'].unique()
ph_hucs = ph_df['HUCNAME_'].unique()
conductivity_hucs = conductivity_df['HUCNAME_'].unique()
results = []
ph_results = []
conductivity_results = []

# def datecheck(string):
#     df = water_df.loc[water_df['HUCNAME_']==string]
#     df['datetime'] = [datetime.strptime(value, '%m/%d/%Y') for value in df['Date']]
#     df['datediff'] = df['datetime'].diff
#     datedifcol = df['datediff']
#     datetimecol = df['datetime']
#     max_diff = max(datedifcol)
#     max_date = max(datetimecol)
#     min_date = min(datetimecol)
#     print(max_diff, max_date, min_date)
#     diff_years = relativedelta(max_date, min_date).years
#     if diff_years >=3 & max_diff <= 7:
#         return True
#     else:
#         return False
                                    


# for each HUC, check if dates are continuous over at least 3 years, build list of suitable HUCs...check

#for each suitable HUC, split temps into quarters by date...check

#calculate variance or stdev of temps and avg temps for each quarter

#for each quarter calculate increase in avg over time

#return suitable hucs by order of highest degree of change, and greatest variability
# Out:
# /Users/josephgeglia/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
water_df
# Out:
#              Date             ModifiedDate  \
# 0      01/01/2012  2020-04-15T14:35:09.607
# 1      01/01/2014  2020-03-10T11:04:49.987
# 2      01/01/2014  2020-03-10T11:16:13.723
# 3      01/01/2014  2020-03-10T11:04:35.813
# 4      01/01/2014  2020-03-10T11:04:18.423
# ...           ...                      ...
# 42068  12/30/2005   2020-03-27T10:35:46.52
# 42069  12/30/2010   2020-03-27T10:36:03.91
# 42070  12/30/2013  2020-03-27T10:36:03.723
# 42071  12/31/2004   2020-03-26T12:02:27.74
# 42072  12/31/2018   2020-03-27T10:36:01.55
#
#                                                 HUCNAME_   Latitude  \
# 0                           Hazel Run-Rappahannock River  38.289800
# 1                                         Totuskey Creek  37.923634
# 2                                         Totuskey Creek  37.886036
# 3                                         Totuskey Creek  37.926034
# 4                                         Totuskey Creek  37.912934
# ...                                                  ...        ...
# 42068  West Branch Little Conestoga Creek-Little Cone...  39.983782
# 42069                                         Lititz Run  40.133611
# 42070                                         Lititz Run  40.133611
# 42071               Little Cocalico Creek-Cocalico Creek  40.187778
# 42072                 Millers Run-Little Conestoga Creek  40.095278
#
#        Longitude Parameter      ParameterName_CBP   ParameterName_CMC  \
# 0     -77.481600      WT.8  WATER TEMPERATURE DEG  Water temperature
# 1     -76.720680      WT.8  WATER TEMPERATURE DEG  Water temperature
# 2     -76.736281      WT.8  WATER TEMPERATURE DEG  Water temperature
# 3     -76.709080      WT.8  WATER TEMPERATURE DEG  Water temperature
# 4     -76.657379      WT.8  WATER TEMPERATURE DEG  Water temperature
# ...          ...       ...                    ...                 ...
# 42068 -76.377848     WT.13  WATER TEMPERATURE DEG  Water Temperature
# 42069 -76.258056     WT.13  WATER TEMPERATURE DEG  Water Temperature
# 42070 -76.258056     WT.13  WATER TEMPERATURE DEG  Water Temperature
# 42071 -76.170000     WT.13  WATER TEMPERATURE DEG  Water Temperature
# 42072 -76.336389     WT.13  WATER TEMPERATURE DEG  Water Temperature
#
#        MeasureValue
# 0               9.0
# 1               6.0
# 2               6.0
# 3               6.0
# 4               5.0
# ...             ...
# 42068           8.0
# 42069           7.0
# 42070           7.5
# 42071           4.0
# 42072           4.5
#
# [42073 rows x 9 columns]

# %%
for huc in hucs:
       
    
    #checks dates for continuity and returns datecheck as boolean
    df = water_df.loc[water_df['HUCNAME_']==huc]
    df['datetime'] = [datetime.strptime(value, '%m/%d/%Y') for value in df['Date']]
    df = df.sort_values(by=['datetime'])
    df['datediff'] = df['datetime'].diff()
    datetimecol = df['datetime']
    min_date = min(datetimecol)
    max_date = max(datetimecol)
    diff_years = relativedelta(max_date, min_date).years
    df = df.dropna()
    datedifcol = df['datediff'].dt.days
    try:
        max_diff = max(datedifcol)
        if diff_years >=3 and max_diff <= 100:
            datecheck = True
        else:
            datecheck = False
    except:
        datecheck = False
    if datecheck == True:
#         results.append()
        #for each suitable HUC, split temps into quarters by date
        df['month'] = [int(value[0:2]) for value in df['Date']]
        df['year'] = [value[6:10] for value in df['Date']]
        df['q'] = ''
        
        df['q'].loc[df['month'] <=3] = 'Q1'
        df['q'].loc[df['month'] >=4] = 'Q2'
        df['q'].loc[df['month'] >=7] = 'Q3'
        df['q'].loc[df['month'] >=10] = 'Q4'
        
        df['Quarter'] = df['q'] + " "+ df['year']
        
        df.drop(columns = ['month', 'year'])
        
        #calculate variance or stdev of temps and avg temps for each quarter
        quarters_list = df['Quarter'].unique()    
        for quarter in quarters_list:
            quarter_df = df.loc[df['Quarter']==quarter]
            values = [value for value in quarter_df['MeasureValue']]
            variance = np.var(values)
            stdev = np.std(values)
            average = np.average(values)
            max_val = max(values)
            min_val = min(values)
            results.append(
                {
                    'huc':huc, 
                    'quarter': quarter,
                    'q': quarter[0:2],
                    'year': quarter[3:7],
                    'var' : variance, 
                    'stdev' : stdev, 
                    'avg' : average, 
                    'max' : max_val, 
                    'min' : min_val,
                    'max_time_diff': max_diff,
                    'max_date': max_date,
                    'min_date': min_date
                }
            )
    else:
        pass

results
# Out:
# /Users/josephgeglia/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/josephgeglia/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# [{'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 18.94,
#   'stdev': 4.352011029397789,
#   'avg': 9.1,
#   'max': 16.0,
#   'min': 2.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2012',
#   'q': 'Q2',
#   'year': '2012',
#   'var': 5.0625,
#   'stdev': 2.25,
#   'avg': 17.25,
#   'max': 21.0,
#   'min': 14.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 4.888888888888889,
#   'stdev': 2.211083193570267,
#   'avg': 23.166666666666668,
#   'max': 25.0,
#   'min': 18.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 20.333333333333332,
#   'stdev': 4.509249752822894,
#   'avg': 11.5,
#   'max': 20.5,
#   'min': 7.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 1.4266493055555556,
#   'stdev': 1.194424256935347,
#   'avg': 5.645833333333333,
#   'max': 9.0,
#   'min': 4.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 34.506874999999994,
#   'stdev': 5.874255271947244,
#   'avg': 15.425,
#   'max': 26.0,
#   'min': 6.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 10.374565972222223,
#   'stdev': 3.2209573067990553,
#   'avg': 24.604166666666668,
#   'max': 30.0,
#   'min': 18.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 24.49826388888889,
#   'stdev': 4.949572091493253,
#   'avg': 11.291666666666666,
#   'max': 20.5,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 3.138888888888889,
#   'stdev': 1.7716909687891083,
#   'avg': 5.583333333333333,
#   'max': 8.0,
#   'min': 1.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 38.535123966942145,
#   'stdev': 6.207666547660413,
#   'avg': 18.818181818181817,
#   'max': 28.0,
#   'min': 8.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 11.124483471074377,
#   'stdev': 3.3353385841731837,
#   'avg': 25.522727272727273,
#   'max': 29.5,
#   'min': 17.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 31.463541666666668,
#   'stdev': 5.609237173329959,
#   'avg': 12.125,
#   'max': 21.0,
#   'min': 6.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 4.670360110803324,
#   'stdev': 2.161101596594506,
#   'avg': 5.973684210526316,
#   'max': 11.0,
#   'min': 3.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 34.326388888888886,
#   'stdev': 5.858872663652018,
#   'avg': 19.666666666666668,
#   'max': 30.5,
#   'min': 10.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 11.509982638888891,
#   'stdev': 3.3926365320925393,
#   'avg': 26.645833333333332,
#   'max': 32.0,
#   'min': 17.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 6.064272211720225,
#   'stdev': 2.4625743058271814,
#   'avg': 13.391304347826088,
#   'max': 18.0,
#   'min': 10.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 13.2225,
#   'stdev': 3.6362755671153417,
#   'avg': 8.95,
#   'max': 15.0,
#   'min': 3.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 16.68359375,
#   'stdev': 4.084555514373626,
#   'avg': 19.1875,
#   'max': 26.0,
#   'min': 12.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 9.826984126984128,
#   'stdev': 3.1348020873707685,
#   'avg': 26.26666666666667,
#   'max': 31.5,
#   'min': 20.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 33.34722222222222,
#   'stdev': 5.774705379690138,
#   'avg': 13.083333333333334,
#   'max': 21.5,
#   'min': 3.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 8.423177083333334,
#   'stdev': 2.9022710216885903,
#   'avg': 8.4375,
#   'max': 15.0,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 12.414930555555557,
#   'stdev': 3.5234827309858576,
#   'avg': 20.541666666666668,
#   'max': 27.0,
#   'min': 14.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 19.181875,
#   'stdev': 4.379711748505831,
#   'avg': 27.425,
#   'max': 42.0,
#   'min': 21.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 23.019097222222225,
#   'stdev': 4.797822133241522,
#   'avg': 12.541666666666666,
#   'max': 20.5,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 8.013888888888888,
#   'stdev': 2.8308812919105044,
#   'avg': 7.166666666666667,
#   'max': 13.0,
#   'min': 2.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 21.959427083333335,
#   'stdev': 4.6860886764265715,
#   'avg': 20.712500000000002,
#   'max': 29.0,
#   'min': 13.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 7.115,
#   'stdev': 2.667395733669828,
#   'avg': 27.6,
#   'max': 31.0,
#   'min': 22.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 40.234375,
#   'stdev': 6.343057228182637,
#   'avg': 13.125,
#   'max': 26.0,
#   'min': 5.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 7.201814058956915,
#   'stdev': 2.683619581639118,
#   'avg': 8.023809523809524,
#   'max': 12.0,
#   'min': 2.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 26.064999999999998,
#   'stdev': 5.105389309347525,
#   'avg': 17.9,
#   'max': 27.0,
#   'min': 8.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 8.749565972222223,
#   'stdev': 2.957966526555401,
#   'avg': 26.729166666666668,
#   'max': 30.5,
#   'min': 19.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 40.20138888888889,
#   'stdev': 6.34045652054242,
#   'avg': 12.416666666666666,
#   'max': 25.0,
#   'min': 4.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 27.26,
#   'stdev': 5.221110992882645,
#   'avg': 9.8,
#   'max': 19.0,
#   'min': 3.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2012',
#   'q': 'Q2',
#   'year': '2012',
#   'var': 5.333333333333333,
#   'stdev': 2.309401076758503,
#   'avg': 20.5,
#   'max': 24.5,
#   'min': 17.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 10.3125,
#   'stdev': 3.2113081446662823,
#   'avg': 27.25,
#   'max': 30.0,
#   'min': 20.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 25.145833333333332,
#   'stdev': 5.014562127776794,
#   'avg': 12.25,
#   'max': 22.5,
#   'min': 8.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 1.6458333333333333,
#   'stdev': 1.282900359861721,
#   'avg': 5.25,
#   'max': 8.0,
#   'min': 4.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 43.839999999999996,
#   'stdev': 6.6211781428987395,
#   'avg': 15.4,
#   'max': 26.0,
#   'min': 7.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 4.951388888888888,
#   'stdev': 2.2251716538031148,
#   'avg': 26.083333333333332,
#   'max': 30.0,
#   'min': 23.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 26.034722222222225,
#   'stdev': 5.102423171613878,
#   'avg': 11.583333333333334,
#   'max': 20.0,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 2.784722222222222,
#   'stdev': 1.668748699541732,
#   'avg': 5.083333333333333,
#   'max': 7.0,
#   'min': 2.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 36.260000000000005,
#   'stdev': 6.021627686929839,
#   'avg': 19.3,
#   'max': 27.5,
#   'min': 12.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 3.9791666666666665,
#   'stdev': 1.9947848672643038,
#   'avg': 25.75,
#   'max': 28.5,
#   'min': 23.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 32.451388888888886,
#   'stdev': 5.696612053570867,
#   'avg': 12.416666666666666,
#   'max': 21.0,
#   'min': 7.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 6.640000000000001,
#   'stdev': 2.5768197453450252,
#   'avg': 5.9,
#   'max': 10.5,
#   'min': 3.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 36.201388888888886,
#   'stdev': 6.0167590020615656,
#   'avg': 19.916666666666668,
#   'max': 30.0,
#   'min': 11.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 6.479166666666667,
#   'stdev': 2.545420724883544,
#   'avg': 26.25,
#   'max': 29.0,
#   'min': 21.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 6.645833333333333,
#   'stdev': 2.577951383043003,
#   'avg': 13.25,
#   'max': 18.0,
#   'min': 10.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 11.229166666666666,
#   'stdev': 3.3509948771471834,
#   'avg': 8.75,
#   'max': 15.0,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 17.70138888888889,
#   'stdev': 4.207301853788112,
#   'avg': 20.583333333333332,
#   'max': 26.0,
#   'min': 14.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 8.459999999999999,
#   'stdev': 2.908607914449797,
#   'avg': 26.7,
#   'max': 31.5,
#   'min': 23.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 34.47222222222222,
#   'stdev': 5.871304984602846,
#   'avg': 12.833333333333334,
#   'max': 21.0,
#   'min': 4.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 7.472222222222221,
#   'stdev': 2.733536577809454,
#   'avg': 8.666666666666666,
#   'max': 14.0,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 9.472222222222223,
#   'stdev': 3.0776975521032313,
#   'avg': 22.166666666666668,
#   'max': 27.0,
#   'min': 18.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 5.0,
#   'stdev': 2.23606797749979,
#   'avg': 27.5,
#   'max': 30.0,
#   'min': 24.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 28.583333333333332,
#   'stdev': 5.346338310781813,
#   'avg': 13.0,
#   'max': 20.5,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 10.24,
#   'stdev': 3.2,
#   'avg': 7.4,
#   'max': 12.0,
#   'min': 2.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 22.868055555555557,
#   'stdev': 4.782055578467857,
#   'avg': 21.083333333333332,
#   'max': 28.0,
#   'min': 14.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 3.6400000000000006,
#   'stdev': 1.9078784028338915,
#   'avg': 27.9,
#   'max': 30.0,
#   'min': 25.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 36.416666666666664,
#   'stdev': 6.034622330077224,
#   'avg': 13.0,
#   'max': 23.0,
#   'min': 6.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 2.4,
#   'stdev': 1.5491933384829668,
#   'avg': 8.5,
#   'max': 11.0,
#   'min': 7.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 17.04,
#   'stdev': 4.127953488110059,
#   'avg': 18.4,
#   'max': 25.0,
#   'min': 12.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 2.388888888888889,
#   'stdev': 1.5456030825826172,
#   'avg': 26.666666666666668,
#   'max': 28.5,
#   'min': 23.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 41.36805555555555,
#   'stdev': 6.431800335485823,
#   'avg': 11.916666666666666,
#   'max': 24.0,
#   'min': 4.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2011',
#   'q': 'Q2',
#   'year': '2011',
#   'var': 14.0625,
#   'stdev': 3.75,
#   'avg': 20.75,
#   'max': 24.5,
#   'min': 17.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2011',
#   'q': 'Q3',
#   'year': '2011',
#   'var': 2.7222222222222228,
#   'stdev': 1.649915822768611,
#   'avg': 22.166666666666668,
#   'max': 24.0,
#   'min': 20.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2011',
#   'q': 'Q4',
#   'year': '2011',
#   'var': 6.888888888888888,
#   'stdev': 2.6246692913372702,
#   'avg': 13.333333333333334,
#   'max': 17.0,
#   'min': 11.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 15.166666666666666,
#   'stdev': 3.8944404818493075,
#   'avg': 14.5,
#   'max': 19.0,
#   'min': 9.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2012',
#   'q': 'Q2',
#   'year': '2012',
#   'var': 6.5,
#   'stdev': 2.5495097567963922,
#   'avg': 17.0,
#   'max': 19.5,
#   'min': 13.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 3.2120014592001764,
#   'stdev': 1.792205752473799,
#   'avg': 24.1,
#   'max': 26.10000038,
#   'min': 20.79999924,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 28.64666828800004,
#   'stdev': 5.352258241901267,
#   'avg': 13.700000126666666,
#   'max': 20.10000038,
#   'min': 7.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 13.876875,
#   'stdev': 3.725167781456293,
#   'avg': 13.475,
#   'max': 19.0,
#   'min': 8.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 6.25,
#   'stdev': 2.5,
#   'avg': 20.0,
#   'max': 22.5,
#   'min': 17.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 11.354999999999999,
#   'stdev': 3.369718089098849,
#   'avg': 21.6,
#   'max': 26.5,
#   'min': 18.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 1.0,
#   'stdev': 1.0,
#   'avg': 14.0,
#   'max': 15.0,
#   'min': 13.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 5.002222222222222,
#   'stdev': 2.2365648262955005,
#   'avg': 8.033333333333333,
#   'max': 10.0,
#   'min': 4.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 21.717688888888894,
#   'stdev': 4.66022412431944,
#   'avg': 20.293333333333333,
#   'max': 27.0,
#   'min': 12.4,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 15.053593750000001,
#   'stdev': 3.8798961004129997,
#   'avg': 23.2125,
#   'max': 29.8,
#   'min': 18.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 25.281875,
#   'stdev': 5.028108491271842,
#   'avg': 11.875,
#   'max': 19.8,
#   'min': 4.4,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 6.652500000000002,
#   'stdev': 2.5792440753057866,
#   'avg': 8.85,
#   'max': 12.8,
#   'min': 6.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 14.22234375,
#   'stdev': 3.7712522787530403,
#   'avg': 19.8625,
#   'max': 24.8,
#   'min': 11.7,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 0.8542857142857146,
#   'stdev': 0.9242757782641038,
#   'avg': 23.8,
#   'max': 25.0,
#   'min': 22.4,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 17.0329,
#   'stdev': 4.127093408199044,
#   'avg': 13.510000000000002,
#   'max': 19.2,
#   'min': 6.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 5.281599999999999,
#   'stdev': 2.2981731875557156,
#   'avg': 8.08,
#   'max': 11.5,
#   'min': 3.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 14.632222222222225,
#   'stdev': 3.8252087815205886,
#   'avg': 17.533333333333335,
#   'max': 24.1,
#   'min': 12.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 3.242499999999999,
#   'stdev': 1.8006943105369104,
#   'avg': 24.25,
#   'max': 26.7,
#   'min': 21.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 18.271733333333334,
#   'stdev': 4.274544810074324,
#   'avg': 14.94,
#   'max': 21.3,
#   'min': 7.8,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 13.065061728395058,
#   'stdev': 3.614562453243139,
#   'avg': 10.02222222222222,
#   'max': 17.9,
#   'min': 5.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 20.765061728395057,
#   'stdev': 4.556869729144674,
#   'avg': 18.522222222222226,
#   'max': 30.4,
#   'min': 12.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 4.3641666666666685,
#   'stdev': 2.0890587992363137,
#   'avg': 23.149999999999995,
#   'max': 27.0,
#   'min': 18.9,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 20.94485207100592,
#   'stdev': 4.576554607016715,
#   'avg': 13.423076923076923,
#   'max': 22.8,
#   'min': 3.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 10.359734651404787,
#   'stdev': 3.2186541677236447,
#   'avg': 10.104838709677418,
#   'max': 17.2,
#   'min': 4.6,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 11.480515122873348,
#   'stdev': 3.388290885221242,
#   'avg': 19.92391304347826,
#   'max': 25.7,
#   'min': 10.2,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 1.9815999999999998,
#   'stdev': 1.407693148381422,
#   'avg': 24.98,
#   'max': 29.2,
#   'min': 22.9,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 50.216483856829804,
#   'stdev': 7.086358998585226,
#   'avg': 13.781621621621623,
#   'max': 24.1,
#   'min': 0.5,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 10.606118626430801,
#   'stdev': 3.256703644243793,
#   'avg': 8.603225806451613,
#   'max': 14.2,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 9.244866863905324,
#   'stdev': 3.0405372656662712,
#   'avg': 20.31153846153846,
#   'max': 27.7,
#   'min': 14.4,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 4.314866863905326,
#   'stdev': 2.0772257614196215,
#   'avg': 23.988461538461536,
#   'max': 27.3,
#   'min': 19.2,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 24.681932015306128,
#   'stdev': 4.968091385563085,
#   'avg': 13.814642857142855,
#   'max': 23.4,
#   'min': 5.9,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 2.107654320987655,
#   'stdev': 1.451776264094318,
#   'avg': 10.088888888888887,
#   'max': 11.8,
#   'min': 7.3,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2020',
#   'q': 'Q2',
#   'year': '2020',
#   'var': 0.5625,
#   'stdev': 0.75,
#   'avg': 22.35,
#   'max': 23.1,
#   'min': 21.6,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 0.20222222222222197,
#   'stdev': 0.4496912521077344,
#   'avg': 26.366666666666664,
#   'max': 27.0,
#   'min': 26.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 34.67187500000001,
#   'stdev': 5.888282856656939,
#   'avg': 10.175,
#   'max': 16.6,
#   'min': 4.2,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 0.3136,
#   'stdev': 0.5599999999999999,
#   'avg': 1.42,
#   'max': 1.7,
#   'min': 0.3,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 21.84583333333333,
#   'stdev': 4.6739526456023635,
#   'avg': 12.85,
#   'max': 16.6,
#   'min': 6.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 4.9266666666666685,
#   'stdev': 2.2196095752781995,
#   'avg': 21.3,
#   'max': 23.8,
#   'min': 17.7,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 35.46857142857144,
#   'stdev': 5.955549632785495,
#   'avg': 8.900000000000002,
#   'max': 18.3,
#   'min': 1.9,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 4.092499999999999,
#   'stdev': 2.0229928324143907,
#   'avg': 3.4499999999999997,
#   'max': 5.0,
#   'min': 0.6,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 19.09333333333333,
#   'stdev': 4.36959189551305,
#   'avg': 20.333333333333332,
#   'max': 27.0,
#   'min': 14.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 6.666666666666666,
#   'stdev': 2.581988897471611,
#   'avg': 19.666666666666668,
#   'max': 22.0,
#   'min': 13.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 23.06172839506173,
#   'stdev': 4.802262841105402,
#   'avg': 5.777777777777778,
#   'max': 12.0,
#   'min': 1.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 0.25,
#   'stdev': 0.5,
#   'avg': 0.5,
#   'max': 1.0,
#   'min': 0.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 26.69387755102041,
#   'stdev': 5.166611805721464,
#   'avg': 14.142857142857142,
#   'max': 21.0,
#   'min': 8.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 2.8888888888888893,
#   'stdev': 1.699673171197595,
#   'avg': 20.333333333333332,
#   'max': 22.0,
#   'min': 18.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 8.222222222222221,
#   'stdev': 2.8674417556808756,
#   'avg': 9.666666666666666,
#   'max': 13.0,
#   'min': 6.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 4.666666666666667,
#   'stdev': 2.160246899469287,
#   'avg': 5.0,
#   'max': 8.0,
#   'min': 3.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 16.88888888888889,
#   'stdev': 4.109609335312651,
#   'avg': 18.666666666666668,
#   'max': 24.0,
#   'min': 14.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 38.88888888888889,
#   'stdev': 6.236095644623236,
#   'avg': 19.666666666666668,
#   'max': 28.0,
#   'min': 13.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 32.666666666666664,
#   'stdev': 5.715476066494082,
#   'avg': 6.0,
#   'max': 14.0,
#   'min': 1.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 1.5555555555555554,
#   'stdev': 1.247219128924647,
#   'avg': 2.6666666666666665,
#   'max': 4.0,
#   'min': 1.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 10.888888888888888,
#   'stdev': 3.2998316455372216,
#   'avg': 14.333333333333334,
#   'max': 18.0,
#   'min': 10.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 2.1666666666666665,
#   'stdev': 1.4719601443879744,
#   'avg': 17.0,
#   'max': 18.5,
#   'min': 15.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 27.555555555555557,
#   'stdev': 5.2493385826745405,
#   'avg': 2.6666666666666665,
#   'max': 10.0,
#   'min': -2.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 4.666666666666667,
#   'stdev': 2.160246899469287,
#   'avg': 1.0,
#   'max': 4.0,
#   'min': -1.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 39.05555555555556,
#   'stdev': 6.249444419750891,
#   'avg': 9.166666666666666,
#   'max': 15.0,
#   'min': 0.5,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 2.8888888888888893,
#   'stdev': 1.699673171197595,
#   'avg': 16.333333333333332,
#   'max': 18.0,
#   'min': 14.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 5.5555555555555545,
#   'stdev': 2.357022603955158,
#   'avg': 1.6666666666666667,
#   'max': 5.0,
#   'min': 0.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 1.5555555555555556,
#   'stdev': 1.247219128924647,
#   'avg': -1.6666666666666667,
#   'max': 0.0,
#   'min': -3.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 6.0,
#   'stdev': 2.449489742783178,
#   'avg': 14.0,
#   'max': 17.0,
#   'min': 11.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 9.555555555555555,
#   'stdev': 3.0912061651652345,
#   'avg': 17.333333333333332,
#   'max': 20.0,
#   'min': 13.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 14.888888888888891,
#   'stdev': 3.8586123009300755,
#   'avg': 2.6666666666666665,
#   'max': 8.0,
#   'min': -1.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q1 2011',
#   'q': 'Q1',
#   'year': '2011',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 0.0,
#   'max': 0.0,
#   'min': 0.0,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q2 2011',
#   'q': 'Q2',
#   'year': '2011',
#   'var': 16.0,
#   'stdev': 4.0,
#   'avg': 13.0,
#   'max': 17.0,
#   'min': 9.0,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q3 2011',
#   'q': 'Q3',
#   'year': '2011',
#   'var': 14.6875,
#   'stdev': 3.832427429188973,
#   'avg': 14.75,
#   'max': 19.0,
#   'min': 10.0,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q4 2011',
#   'q': 'Q4',
#   'year': '2011',
#   'var': 5.138888888888889,
#   'stdev': 2.266911751455907,
#   'avg': 4.333333333333333,
#   'max': 7.5,
#   'min': 1.5,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 4.546875,
#   'stdev': 2.1323402636539974,
#   'avg': 1.125,
#   'max': 4.0,
#   'min': -2.0,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q2 2012',
#   'q': 'Q2',
#   'year': '2012',
#   'var': 8.666666666666666,
#   'stdev': 2.943920288775949,
#   'avg': 14.0,
#   'max': 17.0,
#   'min': 10.0,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 2.25,
#   'stdev': 1.5,
#   'avg': 16.2,
#   'max': 17.7,
#   'min': 14.7,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 13.066718749999998,
#   'stdev': 3.61479166066317,
#   'avg': 2.9625,
#   'max': 9.1,
#   'min': 0.0,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 0.02888888888888889,
#   'stdev': 0.16996731711975951,
#   'avg': 0.06666666666666667,
#   'max': 0.3,
#   'min': -0.1,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 29.202222222222222,
#   'stdev': 5.403908050866726,
#   'avg': 14.233333333333334,
#   'max': 22.0,
#   'min': 8.0,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 20.094399999999997,
#   'stdev': 4.482677771154201,
#   'avg': 19.259999999999998,
#   'max': 24.0,
#   'min': 12.3,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 70.3264,
#   'stdev': 8.38608371052901,
#   'avg': 10.46,
#   'max': 20.0,
#   'min': -0.3,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 0.062499999999999944,
#   'stdev': 0.2499999999999999,
#   'avg': 2.05,
#   'max': 2.3,
#   'min': 1.8,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 74.42,
#   'stdev': 8.62670273047588,
#   'avg': 17.900000000000002,
#   'max': 24.0,
#   'min': 5.7,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 6.242040816326531,
#   'stdev': 2.498407656153521,
#   'avg': 17.82857142857143,
#   'max': 23.0,
#   'min': 15.7,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 28.650000000000006,
#   'stdev': 5.352569476429055,
#   'avg': 7.3,
#   'max': 15.0,
#   'min': 2.2,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 0.022500000000000006,
#   'stdev': 0.15000000000000002,
#   'avg': 0.75,
#   'max': 0.9,
#   'min': 0.6,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 5.546666666666666,
#   'stdev': 2.355136231020759,
#   'avg': 13.799999999999999,
#   'max': 16.2,
#   'min': 10.6,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 3.4488888888888893,
#   'stdev': 1.8571184369578826,
#   'avg': 17.26666666666667,
#   'max': 19.8,
#   'min': 15.4,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 4.9,
#   'max': 4.9,
#   'min': 4.9,
#   'max_time_diff': 94,
#   'max_date': Timestamp('2018-10-07 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Catatonk Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 7.289999999999999,
# ...
#   'stdev': 3.130891141327494,
#   'avg': 17.245454545454546,
#   'max': 24.0,
#   'min': 14.0,
#   'max_time_diff': 40,
#   'max_date': Timestamp('2017-08-05 00:00:00'),
#   'min_date': Timestamp('2009-01-05 00:00:00')},
#  {'huc': 'East Branch Antietam Creek',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 10.02809917355372,
#   'stdev': 3.166717412961523,
#   'avg': 10.69090909090909,
#   'max': 16.0,
#   'min': 6.0,
#   'max_time_diff': 40,
#   'max_date': Timestamp('2017-08-05 00:00:00'),
#   'min_date': Timestamp('2009-01-05 00:00:00')},
#  {'huc': 'East Branch Antietam Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 5.285123966942149,
#   'stdev': 2.2989397484366894,
#   'avg': 5.318181818181818,
#   'max': 9.5,
#   'min': 1.5,
#   'max_time_diff': 40,
#   'max_date': Timestamp('2017-08-05 00:00:00'),
#   'min_date': Timestamp('2009-01-05 00:00:00')},
#  {'huc': 'East Branch Antietam Creek',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 8.643598615916956,
#   'stdev': 2.9399997646117177,
#   'avg': 14.558823529411764,
#   'max': 21.0,
#   'min': 8.5,
#   'max_time_diff': 40,
#   'max_date': Timestamp('2017-08-05 00:00:00'),
#   'min_date': Timestamp('2009-01-05 00:00:00')},
#  {'huc': 'East Branch Antietam Creek',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 6.387755102040816,
#   'stdev': 2.5274008589934476,
#   'avg': 19.571428571428573,
#   'max': 23.0,
#   'min': 16.0,
#   'max_time_diff': 40,
#   'max_date': Timestamp('2017-08-05 00:00:00'),
#   'min_date': Timestamp('2009-01-05 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q4 1999',
#   'q': 'Q4',
#   'year': '1999',
#   'var': 12.666666666666666,
#   'stdev': 3.559026084010437,
#   'avg': 7.0,
#   'max': 12.0,
#   'min': 4.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q1 2000',
#   'q': 'Q1',
#   'year': '2000',
#   'var': 8.222222222222221,
#   'stdev': 2.8674417556808756,
#   'avg': 4.333333333333333,
#   'max': 8.0,
#   'min': 1.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q2 2000',
#   'q': 'Q2',
#   'year': '2000',
#   'var': 20.22222222222222,
#   'stdev': 4.496912521077347,
#   'avg': 14.333333333333334,
#   'max': 18.0,
#   'min': 8.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q3 2000',
#   'q': 'Q3',
#   'year': '2000',
#   'var': 2.0,
#   'stdev': 1.4142135623730951,
#   'avg': 19.0,
#   'max': 20.0,
#   'min': 17.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q4 2000',
#   'q': 'Q4',
#   'year': '2000',
#   'var': 18.0,
#   'stdev': 4.242640687119285,
#   'avg': 7.0,
#   'max': 10.0,
#   'min': 1.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q1 2001',
#   'q': 'Q1',
#   'year': '2001',
#   'var': 4.666666666666667,
#   'stdev': 2.160246899469287,
#   'avg': 2.0,
#   'max': 5.0,
#   'min': 0.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q2 2001',
#   'q': 'Q2',
#   'year': '2001',
#   'var': 8.666666666666666,
#   'stdev': 2.943920288775949,
#   'avg': 13.0,
#   'max': 16.0,
#   'min': 9.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q3 2001',
#   'q': 'Q3',
#   'year': '2001',
#   'var': 8.222222222222223,
#   'stdev': 2.8674417556808756,
#   'avg': 21.333333333333332,
#   'max': 25.0,
#   'min': 18.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q4 2001',
#   'q': 'Q4',
#   'year': '2001',
#   'var': 29.555555555555557,
#   'stdev': 5.436502143433364,
#   'avg': 9.333333333333334,
#   'max': 17.0,
#   'min': 5.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q1 2002',
#   'q': 'Q1',
#   'year': '2002',
#   'var': 12.666666666666666,
#   'stdev': 3.559026084010437,
#   'avg': 3.0,
#   'max': 8.0,
#   'min': 0.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q2 2002',
#   'q': 'Q2',
#   'year': '2002',
#   'var': 1.5555555555555556,
#   'stdev': 1.247219128924647,
#   'avg': 13.333333333333334,
#   'max': 15.0,
#   'min': 12.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q3 2002',
#   'q': 'Q3',
#   'year': '2002',
#   'var': 2.8888888888888893,
#   'stdev': 1.699673171197595,
#   'avg': 16.333333333333332,
#   'max': 18.0,
#   'min': 14.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Doubling Gap Creek',
#   'quarter': 'Q4 2002',
#   'q': 'Q4',
#   'year': '2002',
#   'var': 9.0,
#   'stdev': 3.0,
#   'avg': 12.0,
#   'max': 15.0,
#   'min': 9.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2002-11-15 00:00:00'),
#   'min_date': Timestamp('1999-09-12 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 0.10888888888888866,
#   'stdev': 0.32998316455372184,
#   'avg': 17.766666666666666,
#   'max': 18.0,
#   'min': 17.3,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 5.0625,
#   'stdev': 2.25,
#   'avg': 10.75,
#   'max': 13.0,
#   'min': 8.5,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 6.5,
#   'stdev': 2.5495097567963922,
#   'avg': 5.5,
#   'max': 8.0,
#   'min': 2.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 19.52,
#   'stdev': 4.418144406874904,
#   'avg': 12.4,
#   'max': 18.0,
#   'min': 7.2,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.8066666666666661,
#   'stdev': 0.8981462390204983,
#   'avg': 21.1,
#   'max': 22.2,
#   'min': 20.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 35.108888888888885,
#   'stdev': 5.925275427259806,
#   'avg': 7.633333333333333,
#   'max': 15.6,
#   'min': 1.4,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 36.35671875,
#   'stdev': 6.029653286052192,
#   'avg': 6.9375,
#   'max': 17.3,
#   'min': 2.75,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 14.858367346938772,
#   'stdev': 3.8546552825043605,
#   'avg': 15.214285714285714,
#   'max': 19.2,
#   'min': 10.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.6303999999999995,
#   'stdev': 0.793977329651168,
#   'avg': 18.34,
#   'max': 19.4,
#   'min': 17.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 27.858367346938774,
#   'stdev': 5.2781026275489165,
#   'avg': 8.314285714285715,
#   'max': 15.8,
#   'min': 3.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 1.3050000000000002,
#   'stdev': 1.1423659658795864,
#   'avg': 3.9,
#   'max': 5.0,
#   'min': 2.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 1.0213888888888898,
#   'stdev': 1.0106378623863692,
#   'avg': 14.983333333333334,
#   'max': 16.3,
#   'min': 13.7,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 2.805432098765432,
#   'stdev': 1.674942416552113,
#   'avg': 18.711111111111112,
#   'max': 23.0,
#   'min': 16.8,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 7.621874999999999,
#   'stdev': 2.760774347895894,
#   'avg': 9.175,
#   'max': 12.2,
#   'min': 5.6,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 4.143999999999999,
#   'stdev': 2.0356817039999155,
#   'avg': 6.3,
#   'max': 8.2,
#   'min': 3.3,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 3.8288888888888866,
#   'stdev': 1.9567546828585556,
#   'avg': 15.133333333333333,
#   'max': 17.9,
#   'min': 13.7,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.039999999999999716,
#   'stdev': 0.1999999999999993,
#   'avg': 19.7,
#   'max': 19.9,
#   'min': 19.5,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-06-20 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 39.71555555555556,
#   'stdev': 6.30202789231812,
#   'avg': 9.133333333333333,
#   'max': 17.8,
#   'min': 3.0,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 8.176300000000001,
#   'stdev': 2.8594230187224836,
#   'avg': 14.61,
#   'max': 17.0,
#   'min': 10.0,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 4.156859504132231,
#   'stdev': 2.038837782691951,
#   'avg': 19.836363636363636,
#   'max': 25.0,
#   'min': 17.6,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 11.810246913580247,
#   'stdev': 3.4366039797422467,
#   'avg': 10.344444444444445,
#   'max': 15.5,
#   'min': 5.3,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 1.5294674556213015,
#   'stdev': 1.2367164006437779,
#   'avg': 2.823076923076923,
#   'max': 4.7,
#   'min': 0.6,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 13.676961772853186,
#   'stdev': 3.698237657703083,
#   'avg': 15.014736842105265,
#   'max': 20.8,
#   'min': 10.5,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 1.4773437500000006,
#   'stdev': 1.2154603037532739,
#   'avg': 18.5875,
#   'max': 20.6,
#   'min': 16.9,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 21.694706994328918,
#   'stdev': 4.6577577217293,
#   'avg': 9.708695652173914,
#   'max': 18.1,
#   'min': 1.4,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 3.9298437500000003,
#   'stdev': 1.9823833509187874,
#   'avg': 3.6375,
#   'max': 7.1,
#   'min': 0.9,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.6848979591836736,
#   'stdev': 0.8275856204548708,
#   'avg': 13.971428571428573,
#   'max': 15.9,
#   'min': 13.4,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 3.912307692307692,
#   'stdev': 1.9779554323360504,
#   'avg': 18.299999999999997,
#   'max': 22.0,
#   'min': 14.8,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.11,
#   'stdev': 0.33166247903553997,
#   'avg': 10.25,
#   'max': 10.7,
#   'min': 9.7,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 1.4593057851239666,
#   'stdev': 1.2080172950433974,
#   'avg': 7.1381818181818195,
#   'max': 9.0,
#   'min': 4.7,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.2918750000000002,
#   'stdev': 0.5402545696243579,
#   'avg': 13.575,
#   'max': 14.4,
#   'min': 13.0,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 1.7160937499999993,
#   'stdev': 1.3099976145016445,
#   'avg': 18.8125,
#   'max': 20.9,
#   'min': 16.7,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')}]

# %%
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#               huc  quarter   q  year        var     stdev        avg   max  \
# 0  Totuskey Creek  Q1 2012  Q1  2012  18.940000  4.352011   9.100000  16.0
# 1  Totuskey Creek  Q2 2012  Q2  2012   5.062500  2.250000  17.250000  21.0
# 2  Totuskey Creek  Q3 2012  Q3  2012   4.888889  2.211083  23.166667  25.0
# 3  Totuskey Creek  Q4 2012  Q4  2012  20.333333  4.509250  11.500000  20.5
# 4  Totuskey Creek  Q1 2013  Q1  2013   1.426649  1.194424   5.645833   9.0
#
#     min  max_time_diff   max_date   min_date
# 0   2.5             37 2019-12-19 2012-01-05
# 1  14.0             37 2019-12-19 2012-01-05
# 2  18.5             37 2019-12-19 2012-01-05
# 3   7.0             37 2019-12-19 2012-01-05
# 4   4.5             37 2019-12-19 2012-01-05

# %%
# ph
for huc in ph_hucs:
       
    
    #checks dates for continuity and returns datecheck as boolean
    df = ph_df.loc[ph_df['HUCNAME_']==huc]
    df['datetime'] = [datetime.strptime(value, '%m/%d/%Y') for value in df['Date']]
    df = df.sort_values(by=['datetime'])
    df['datediff'] = df['datetime'].diff()
    datetimecol = df['datetime']
    min_date = min(datetimecol)
    max_date = max(datetimecol)
    diff_years = relativedelta(max_date, min_date).years
    df = df.dropna()
    datedifcol = df['datediff'].dt.days
    try:
        max_diff = max(datedifcol)
        if diff_years >=3 and max_diff <= 100:
            datecheck = True
        else:
            datecheck = False
    except:
        datecheck = False
    if datecheck == True:
#         results.append()
        #for each suitable HUC, split temps into quarters by date
        df['month'] = [int(value[0:2]) for value in df['Date']]
        df['year'] = [value[6:10] for value in df['Date']]
        df['q'] = ''
        
        df['q'].loc[df['month'] <=3] = 'Q1'
        df['q'].loc[df['month'] >=4] = 'Q2'
        df['q'].loc[df['month'] >=7] = 'Q3'
        df['q'].loc[df['month'] >=10] = 'Q4'
        
        df['Quarter'] = df['q'] + " "+ df['year']
        
        df.drop(columns = ['month', 'year'])
        
        #calculate variance or stdev of temps and avg temps for each quarter
        quarters_list = df['Quarter'].unique()    
        for quarter in quarters_list:
            quarter_df = df.loc[df['Quarter']==quarter]
            values = [value for value in quarter_df['MeasureValue']]
            variance = np.var(values)
            stdev = np.std(values)
            average = np.average(values)
            max_val = max(values)
            min_val = min(values)
            ph_results.append(
                {
                    'huc':huc, 
                    'quarter': quarter,
                    'q': quarter[0:2],
                    'year': quarter[3:7],
                    'var' : variance, 
                    'stdev' : stdev, 
                    'avg' : average, 
                    'max' : max_val, 
                    'min' : min_val,
                    'max_time_diff': max_diff,
                    'max_date': max_date,
                    'min_date': min_date
                }
            )
    else:
        pass

ph_results
# Out:
# /Users/josephgeglia/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [{'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 6.55,
#   'max': 6.55,
#   'min': 6.55,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 0.6450000000000008,
#   'stdev': 0.8031189202104511,
#   'avg': 8.58,
#   'max': 9.63,
#   'min': 7.68,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 0.030624999999999937,
#   'stdev': 0.17499999999999982,
#   'avg': 7.995,
#   'max': 8.17,
#   'min': 7.82,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 0.10508888888888905,
#   'stdev': 0.32417416443771246,
#   'avg': 7.9433333333333325,
#   'max': 8.4,
#   'min': 7.68,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 0.0059555555555555985,
#   'stdev': 0.07717224601860179,
#   'avg': 7.876666666666666,
#   'max': 7.95,
#   'min': 7.77,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.4171555555555559,
#   'stdev': 0.6458758050550863,
#   'avg': 8.503333333333334,
#   'max': 9.39,
#   'min': 7.87,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.18408888888888897,
#   'stdev': 0.42905581092544237,
#   'avg': 8.566666666666668,
#   'max': 8.88,
#   'min': 7.96,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.5928222222222223,
#   'stdev': 0.7699494932930486,
#   'avg': 8.536666666666667,
#   'max': 9.52,
#   'min': 7.64,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.0178122448979592,
#   'stdev': 0.13346252244716192,
#   'avg': 7.691428571428571,
#   'max': 7.96,
#   'min': 7.52,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.32702222222222194,
#   'stdev': 0.5718585683735288,
#   'avg': 7.573333333333333,
#   'max': 8.26,
#   'min': 6.86,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.03344897959183676,
#   'stdev': 0.1828906219351795,
#   'avg': 7.1971428571428575,
#   'max': 7.5,
#   'min': 6.96,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.010099999999999986,
#   'stdev': 0.10049875621120884,
#   'avg': 7.47,
#   'max': 7.56,
#   'min': 7.3,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.40918055555555527,
#   'stdev': 0.6396722250930982,
#   'avg': 8.088333333333333,
#   'max': 8.84,
#   'min': 7.13,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.0971555555555556,
#   'stdev': 0.3116978594016257,
#   'avg': 7.423333333333334,
#   'max': 7.98,
#   'min': 7.01,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.01551874999999999,
#   'stdev': 0.12457427503300988,
#   'avg': 7.6475,
#   'max': 7.79,
#   'min': 7.45,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.22997600000000012,
#   'stdev': 0.4795581299488104,
#   'avg': 7.578,
#   'max': 8.49,
#   'min': 7.1,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.007355555555555553,
#   'stdev': 0.08576453553512403,
#   'avg': 7.163333333333333,
#   'max': 7.27,
#   'min': 7.06,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.060024999999999835,
#   'stdev': 0.24499999999999966,
#   'avg': 7.605,
#   'max': 7.85,
#   'min': 7.36,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 0.2393555555555558,
#   'stdev': 0.48923977307201405,
#   'avg': 8.836666666666668,
#   'max': 9.3,
#   'min': 8.16,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 0.2031500000000001,
#   'stdev': 0.45072164358947764,
#   'avg': 8.23,
#   'max': 8.8,
#   'min': 7.57,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.3705867768595042,
#   'stdev': 0.6087583895598517,
#   'avg': 8.126363636363637,
#   'max': 9.81,
#   'min': 7.57,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.16314228395061717,
#   'stdev': 0.40390875696203615,
#   'avg': 8.062777777777779,
#   'max': 8.78,
#   'min': 7.54,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.20765917159763297,
#   'stdev': 0.45569635899097655,
#   'avg': 7.841538461538462,
#   'max': 8.77,
#   'min': 7.44,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.646686426592798,
#   'stdev': 0.8041681581564878,
#   'avg': 8.043684210526315,
#   'max': 9.88,
#   'min': 7.45,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.535796484375,
#   'stdev': 0.7319812049328863,
#   'avg': 7.786875,
#   'max': 8.66,
#   'min': 6.86,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.030894139886578444,
#   'stdev': 0.1757672890118592,
#   'avg': 7.154347826086958,
#   'max': 7.63,
#   'min': 6.91,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.06842343749999999,
#   'stdev': 0.2615787405352354,
#   'avg': 7.87625,
#   'max': 8.38,
#   'min': 7.45,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.1012489795918367,
#   'stdev': 0.31819644811316905,
#   'avg': 7.147142857142858,
#   'max': 7.79,
#   'min': 6.78,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.20150177514792905,
#   'stdev': 0.44888949101970416,
#   'avg': 7.314615384615384,
#   'max': 8.21,
#   'min': 6.78,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.08968593750000001,
#   'stdev': 0.2994761050568142,
#   'avg': 7.3412500000000005,
#   'max': 7.93,
#   'min': 6.92,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.18098347107438026,
#   'stdev': 0.4254215216398675,
#   'avg': 7.462727272727273,
#   'max': 8.58,
#   'min': 7.07,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.026468750000000034,
#   'stdev': 0.16269219403523955,
#   'avg': 7.2275,
#   'max': 7.46,
#   'min': 7.02,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.08106875,
#   'stdev': 0.2847257452356565,
#   'avg': 7.1325,
#   'max': 7.54,
#   'min': 6.79,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.6,
#   'max': 7.6,
#   'min': 7.6,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 0.010000000000000018,
#   'stdev': 0.10000000000000009,
#   'avg': 7.9,
#   'max': 8.0,
#   'min': 7.8,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 0.0024999999999999823,
#   'stdev': 0.04999999999999982,
#   'avg': 8.350000000000001,
#   'max': 8.4,
#   'min': 8.3,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 0.08999999999999989,
#   'stdev': 0.2999999999999998,
#   'avg': 8.2,
#   'max': 8.5,
#   'min': 7.9,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 0.009999999999999929,
#   'stdev': 0.09999999999999964,
#   'avg': 8.1,
#   'max': 8.2,
#   'min': 8.0,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.0024999999999999823,
#   'stdev': 0.04999999999999982,
#   'avg': 8.45,
#   'max': 8.5,
#   'min': 8.4,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.022500000000000107,
#   'stdev': 0.15000000000000036,
#   'avg': 7.25,
#   'max': 7.4,
#   'min': 7.1,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.04000000000000007,
#   'stdev': 0.20000000000000018,
#   'avg': 8.2,
#   'max': 8.4,
#   'min': 8.0,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.0399999999999999,
#   'stdev': 0.19999999999999973,
#   'avg': 8.0,
#   'max': 8.2,
#   'min': 7.8,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.0399999999999999,
#   'stdev': 0.19999999999999973,
#   'avg': 7.9,
#   'max': 8.1,
#   'min': 7.7,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.009999999999999929,
#   'stdev': 0.09999999999999964,
#   'avg': 8.1,
#   'max': 8.2,
#   'min': 8.0,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.15999999999999992,
#   'stdev': 0.3999999999999999,
#   'avg': 8.1,
#   'max': 8.5,
#   'min': 7.7,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.0024999999999999823,
#   'stdev': 0.04999999999999982,
#   'avg': 7.75,
#   'max': 7.8,
#   'min': 7.7,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.02249999999999997,
#   'stdev': 0.1499999999999999,
#   'avg': 7.65,
#   'max': 7.8,
#   'min': 7.5,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Rapid Run',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.4,
#   'max': 7.4,
#   'min': 7.4,
#   'max_time_diff': 98,
#   'max_date': Timestamp('2018-12-02 00:00:00'),
#   'min_date': Timestamp('2015-06-06 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 0.025175963384834733,
#   'stdev': 0.15866935238046045,
#   'avg': 7.0479999542,
#   'max': 7.239999771,
#   'min': 6.8000001910000005,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2012',
#   'q': 'Q2',
#   'year': '2012',
#   'var': 0.013933343326675965,
#   'stdev': 0.11803958372798493,
#   'avg': 7.059999863166667,
#   'max': 7.21999979,
#   'min': 6.909999847000001,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 0.08281383908335115,
#   'stdev': 0.28777393746368196,
#   'avg': 7.141666730333334,
#   'max': 7.449999808999999,
#   'min': 6.5500001910000005,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 0.00848888702223533,
#   'stdev': 0.09213515627726113,
#   'avg': 7.233333349333332,
#   'max': 7.349999905,
#   'min': 7.090000152999999,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 0.04021927083333335,
#   'stdev': 0.20054742789009622,
#   'avg': 7.23125,
#   'max': 7.57,
#   'min': 6.81,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 0.027832750000000007,
#   'stdev': 0.1668315018214486,
#   'avg': 7.1465000000000005,
#   'max': 7.48,
#   'min': 6.87,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 0.057149305555555585,
#   'stdev': 0.2390592093092328,
#   'avg': 7.065833333333333,
#   'max': 7.5,
#   'min': 6.46,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 0.05494930555555557,
#   'stdev': 0.23441268215596947,
#   'avg': 7.210833333333333,
#   'max': 7.58,
#   'min': 6.81,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 0.20000763888888895,
#   'stdev': 0.44722213595582333,
#   'avg': 7.364166666666667,
#   'max': 8.71,
#   'min': 6.7,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 0.05558780991735534,
#   'stdev': 0.23577067230119048,
#   'avg': 7.08590909090909,
#   'max': 7.79,
#   'min': 6.75,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 0.044448966942148775,
#   'stdev': 0.21082923645013937,
#   'avg': 7.123181818181819,
#   'max': 7.59,
#   'min': 6.79,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 0.07115763888888889,
#   'stdev': 0.2667538919845199,
#   'avg': 7.314166666666666,
#   'max': 7.81,
#   'min': 6.96,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 0.15485484764542928,
#   'stdev': 0.3935160068477892,
#   'avg': 7.263684210526315,
#   'max': 8.03,
#   'min': 6.69,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 0.0718222222222222,
#   'stdev': 0.2679966832298904,
#   'avg': 7.053333333333334,
#   'max': 7.55,
#   'min': 6.61,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 0.03245260416666666,
#   'stdev': 0.1801460634226201,
#   'avg': 7.001249999999999,
#   'max': 7.31,
#   'min': 6.72,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 0.032706238185255185,
#   'stdev': 0.18084866099934271,
#   'avg': 7.1573913043478266,
#   'max': 7.5,
#   'min': 6.82,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 0.35708874999999984,
#   'stdev': 0.5975690336689141,
#   'avg': 7.3875,
#   'max': 9.12,
#   'min': 6.66,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 0.14281093749999993,
#   'stdev': 0.37790334412386445,
#   'avg': 7.18875,
#   'max': 8.27,
#   'min': 6.52,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.031005442176870773,
#   'stdev': 0.17608362268215286,
#   'avg': 7.014285714285715,
#   'max': 7.34,
#   'min': 6.68,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.1515498263888888,
#   'stdev': 0.38929401021450205,
#   'avg': 7.204583333333335,
#   'max': 8.12,
#   'min': 6.41,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.2528604166666667,
#   'stdev': 0.5028522811588575,
#   'avg': 7.4175,
#   'max': 8.84,
#   'min': 6.77,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.07993888888888888,
#   'stdev': 0.28273466163328626,
#   'avg': 7.218333333333334,
#   'max': 7.91,
#   'min': 6.8,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.10102475000000002,
#   'stdev': 0.31784390823169795,
#   'avg': 7.025499999999999,
#   'max': 7.71,
#   'min': 6.38,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.05300555555555556,
#   'stdev': 0.23022935424388344,
#   'avg': 7.173333333333333,
#   'max': 7.62,
#   'min': 6.55,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.09993875236294895,
#   'stdev': 0.31613091016689426,
#   'avg': 7.187826086956522,
#   'max': 7.77,
#   'min': 6.6,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.24364375000000002,
#   'stdev': 0.4936028261669498,
#   'avg': 6.7075000000000005,
#   'max': 7.82,
#   'min': 5.6,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.09011274999999994,
#   'stdev': 0.3001878578490475,
#   'avg': 6.7765,
#   'max': 7.52,
#   'min': 6.23,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.1544666666666666,
#   'stdev': 0.39302247603243584,
#   'avg': 6.5950000000000015,
#   'max': 7.56,
#   'min': 5.92,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.08841814058956912,
#   'stdev': 0.2973518800841339,
#   'avg': 6.827619047619048,
#   'max': 7.54,
#   'min': 6.45,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.28967600000000016,
#   'stdev': 0.5382155701946946,
#   'avg': 6.852000000000001,
#   'max': 8.14,
#   'min': 6.19,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.09258263888888885,
#   'stdev': 0.304273953681364,
#   'avg': 6.940833333333334,
#   'max': 7.59,
#   'min': 6.39,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Totuskey Creek',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 0.0922270833333333,
#   'stdev': 0.3036891228433006,
#   'avg': 7.187499999999999,
#   'max': 7.89,
#   'min': 6.81,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 0.02170397304481966,
#   'stdev': 0.14732268340218238,
#   'avg': 6.9359999656,
#   'max': 7.159999847000001,
#   'min': 6.75,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2012',
#   'q': 'Q2',
#   'year': '2012',
#   'var': 0.11835566432336193,
#   'stdev': 0.3440285806780622,
#   'avg': 7.016666730333333,
#   'max': 7.340000152999999,
#   'min': 6.409999847000001,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 0.0073472033527968,
#   'stdev': 0.08571582906789621,
#   'avg': 6.8383333015,
#   'max': 6.949999809,
#   'min': 6.690000057000001,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 0.02391388655781039,
#   'stdev': 0.15464115415312443,
#   'avg': 6.898333310999999,
#   'max': 7.170000076,
#   'min': 6.699999809,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 0.027913888888888905,
#   'stdev': 0.16707450101343682,
#   'avg': 7.011666666666667,
#   'max': 7.21,
#   'min': 6.8,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 0.017600000000000043,
#   'stdev': 0.13266499161421616,
#   'avg': 7.039999999999999,
#   'max': 7.21,
#   'min': 6.81,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 0.01275555555555555,
#   'stdev': 0.11294049564064941,
#   'avg': 6.933333333333333,
#   'max': 7.12,
#   'min': 6.78,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 0.006633333333333359,
#   'stdev': 0.08144527815247093,
#   'avg': 6.989999999999999,
#   'max': 7.11,
#   'min': 6.85,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 0.09929166666666656,
#   'stdev': 0.3151058023373523,
#   'avg': 7.1450000000000005,
#   'max': 7.56,
#   'min': 6.71,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 0.035343999999999966,
#   'stdev': 0.18799999999999992,
#   'avg': 6.894,
#   'max': 7.22,
#   'min': 6.67,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 0.03175555555555561,
#   'stdev': 0.1782008853949823,
#   'avg': 6.873333333333332,
#   'max': 7.15,
#   'min': 6.59,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 0.0468888888888889,
#   'stdev': 0.21653842358548955,
#   'avg': 7.223333333333334,
#   'max': 7.43,
#   'min': 6.84,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 0.12193599999999985,
#   'stdev': 0.3491933561796385,
#   'avg': 7.231999999999999,
#   'max': 7.63,
#   'min': 6.65,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 0.12292500000000002,
#   'stdev': 0.3506066171651642,
#   'avg': 6.885000000000001,
#   'max': 7.55,
#   'min': 6.52,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 0.005055555555555592,
#   'stdev': 0.07110243002567206,
#   'avg': 6.666666666666667,
#   'max': 6.78,
#   'min': 6.56,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 0.00312222222222221,
#   'stdev': 0.055876848714133925,
#   'avg': 6.886666666666667,
#   'max': 7.01,
#   'min': 6.85,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 0.0600472222222222,
#   'stdev': 0.24504534727723806,
#   'avg': 7.041666666666667,
#   'max': 7.4,
#   'min': 6.73,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 0.10932222222222227,
#   'stdev': 0.3306391117551314,
#   'avg': 7.083333333333333,
#   'max': 7.61,
#   'min': 6.7,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.015704000000000006,
#   'stdev': 0.12531560158256436,
#   'avg': 6.754,
#   'max': 6.92,
#   'min': 6.55,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.0714916666666666,
#   'stdev': 0.2673792562385246,
#   'avg': 6.875,
#   'max': 7.26,
#   'min': 6.53,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.0588555555555555,
#   'stdev': 0.24260163963905004,
#   'avg': 7.1066666666666665,
#   'max': 7.5,
#   'min': 6.87,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.019880555555555585,
#   'stdev': 0.14099842394706255,
#   'avg': 7.088333333333334,
#   'max': 7.29,
#   'min': 6.93,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.014879999999999999,
#   'stdev': 0.12198360545581524,
#   'avg': 6.959999999999999,
#   'max': 7.1,
#   'min': 6.77,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.007422222222222229,
#   'stdev': 0.08615231988880061,
#   'avg': 7.153333333333333,
#   'max': 7.3,
#   'min': 7.05,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.030266666666666664,
#   'stdev': 0.17397317800933185,
#   'avg': 7.02,
#   'max': 7.34,
#   'min': 6.76,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.1407555555555555,
#   'stdev': 0.3751740336904401,
#   'avg': 6.533333333333334,
#   'max': 6.93,
#   'min': 5.83,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.040999999999999974,
#   'stdev': 0.2024845673131658,
#   'avg': 6.55,
#   'max': 6.84,
#   'min': 6.25,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.06682222222222216,
#   'stdev': 0.25849994627121714,
#   'avg': 6.443333333333334,
#   'max': 6.76,
#   'min': 6.04,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.018575999999999978,
#   'stdev': 0.13629380029920649,
#   'avg': 6.6579999999999995,
#   'max': 6.88,
#   'min': 6.5,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.1376240000000002,
#   'stdev': 0.3709770882413093,
#   'avg': 6.566000000000001,
#   'max': 7.19,
#   'min': 6.1,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.049433333333333364,
#   'stdev': 0.22233608194203064,
#   'avg': 6.579999999999999,
#   'max': 6.86,
#   'min': 6.26,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Little Totuskey Creek',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 0.012088888888888863,
#   'stdev': 0.10994948334980416,
#   'avg': 6.836666666666666,
#   'max': 7.02,
#   'min': 6.7,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2019-12-19 00:00:00'),
#   'min_date': Timestamp('2012-01-05 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2011',
#   'q': 'Q2',
#   'year': '2011',
#   'var': 0.03239993826002932,
#   'stdev': 0.17999982849999974,
#   'avg': 6.8099999425,
#   'max': 6.989999771,
#   'min': 6.630000114,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2011',
#   'q': 'Q3',
#   'year': '2011',
#   'var': 0.009955570471138432,
#   'stdev': 0.09977760505814134,
#   'avg': 6.963333289,
#   'max': 7.070000172,
#   'min': 6.829999924,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2011',
#   'q': 'Q4',
#   'year': '2011',
#   'var': 0.020422210862226935,
#   'stdev': 0.14290630098853913,
#   'avg': 6.803333441333334,
#   'max': 6.9800000189999984,
#   'min': 6.630000114,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 0.5366221779733419,
#   'stdev': 0.7325450006472926,
#   'avg': 6.236666679333333,
#   'max': 6.869999886,
#   'min': 5.210000038,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2012',
#   'q': 'Q2',
#   'year': '2012',
#   'var': 0.0016888856488904622,
#   'stdev': 0.041096053933321414,
#   'avg': 6.8433332443333335,
#   'max': 6.889999866,
#   'min': 6.789999962,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2012',
#   'q': 'Q3',
#   'year': '2012',
#   'var': 0.08501596525121466,
#   'stdev': 0.2915749736366526,
#   'avg': 7.1719999312,
#   'max': 7.699999808999999,
#   'min': 6.900000095,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2012',
#   'q': 'Q4',
#   'year': '2012',
#   'var': 0.03208882758225151,
#   'stdev': 0.17913354678075102,
#   'avg': 6.946666717666667,
#   'max': 7.199999809,
#   'min': 6.820000172,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 0.05685000000000001,
#   'stdev': 0.2384323803513273,
#   'avg': 6.91,
#   'max': 7.14,
#   'min': 6.51,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2013',
#   'q': 'Q2',
#   'year': '2013',
#   'var': 0.11902500000000013,
#   'stdev': 0.3450000000000002,
#   'avg': 6.595000000000001,
#   'max': 6.94,
#   'min': 6.25,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2013',
#   'q': 'Q3',
#   'year': '2013',
#   'var': 0.019149999999999973,
#   'stdev': 0.13838352503098036,
#   'avg': 6.6499999999999995,
#   'max': 6.85,
#   'min': 6.46,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2013',
#   'q': 'Q4',
#   'year': '2013',
#   'var': 0.008099999999999975,
#   'stdev': 0.08999999999999986,
#   'avg': 6.62,
#   'max': 6.71,
#   'min': 6.53,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 0.5485333333333337,
#   'stdev': 0.7406303621465526,
#   'avg': 7.18,
#   'max': 8.56,
#   'min': 6.48,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2014',
#   'q': 'Q2',
#   'year': '2014',
#   'var': 0.177520987654321,
#   'stdev': 0.42133239568578273,
#   'avg': 7.131111111111112,
#   'max': 7.6,
#   'min': 6.38,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2014',
#   'q': 'Q3',
#   'year': '2014',
#   'var': 0.24432500000000018,
#   'stdev': 0.49429242357131087,
#   'avg': 7.154999999999999,
#   'max': 7.99,
#   'min': 6.51,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2014',
#   'q': 'Q4',
#   'year': '2014',
#   'var': 1.566775,
#   'stdev': 1.2517088319573366,
#   'avg': 6.705,
#   'max': 7.88,
#   'min': 4.3,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 0.28761875000000003,
#   'stdev': 0.5363009882519331,
#   'avg': 7.2475,
#   'max': 7.92,
#   'min': 6.47,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2015',
#   'q': 'Q2',
#   'year': '2015',
#   'var': 0.1323387755102041,
#   'stdev': 0.36378396818744513,
#   'avg': 7.145714285714285,
#   'max': 7.84,
#   'min': 6.72,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2015',
#   'q': 'Q3',
#   'year': '2015',
#   'var': 0.2258816326530613,
#   'stdev': 0.4752700628622229,
#   'avg': 7.224285714285715,
#   'max': 7.95,
#   'min': 6.55,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2015',
#   'q': 'Q4',
#   'year': '2015',
#   'var': 0.1353950617283951,
#   'stdev': 0.36796067959551754,
#   'avg': 7.402222222222223,
#   'max': 7.74,
#   'min': 6.6,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 0.21558400000000008,
#   'stdev': 0.4643102411104025,
#   'avg': 7.056,
#   'max': 8.05,
#   'min': 6.45,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 0.11747500000000001,
#   'stdev': 0.34274626183227735,
#   'avg': 6.655,
#   'max': 6.96,
#   'min': 6.08,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.07847500000000004,
#   'stdev': 0.28013389655662885,
#   'avg': 7.13,
#   'max': 7.59,
#   'min': 6.75,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.1284515555555555,
#   'stdev': 0.3584013888861977,
#   'avg': 7.185333333333333,
#   'max': 7.8,
#   'min': 6.63,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.2855162629757784,
#   'stdev': 0.5343372184077939,
#   'avg': 7.381176470588236,
#   'max': 8.5,
#   'min': 6.52,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.206544,
#   'stdev': 0.45447112119473554,
#   'avg': 7.034,
#   'max': 8.1,
#   'min': 6.0,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.05292077562326868,
#   'stdev': 0.23004515996488317,
#   'avg': 7.070526315789474,
#   'max': 7.45,
#   'min': 6.65,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.5623613636363637,
#   'stdev': 0.7499075700620469,
#   'avg': 7.395,
#   'max': 10.08,
#   'min': 6.48,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.360014058956916,
#   'stdev': 0.600011715683049,
#   'avg': 7.429523809523811,
#   'max': 8.6,
#   'min': 6.46,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.3368311224489796,
#   'stdev': 0.5803715382830034,
#   'avg': 7.297857142857143,
#   'max': 8.9,
#   'min': 6.45,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.15519909297052145,
#   'stdev': 0.3939531608840338,
#   'avg': 7.1590476190476195,
#   'max': 7.77,
#   'min': 6.48,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.22114482758620688,
#   'stdev': 0.47026038275215876,
#   'avg': 7.1000000000000005,
#   'max': 7.9,
#   'min': 6.19,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.2210374291115312,
#   'stdev': 0.47014617845041684,
#   'avg': 7.021304347826086,
#   'max': 8.13,
#   'min': 6.33,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.06976666666666663,
#   'stdev': 0.26413380447543366,
#   'avg': 6.973333333333333,
#   'max': 7.35,
#   'min': 6.41,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.09077654320987653,
#   'stdev': 0.30129145890628317,
#   'avg': 6.988888888888889,
#   'max': 7.8,
#   'min': 6.58,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 0.12822358276643997,
#   'stdev': 0.3580832064848057,
#   'avg': 6.98952380952381,
#   'max': 7.52,
#   'min': 6.46,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 0.11084999999999992,
#   'stdev': 0.33294143629172973,
#   'avg': 7.569999999999999,
#   'max': 7.91,
#   'min': 7.03,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2020-03-08 00:00:00'),
# ...
#   'max': 5.0,
#   'min': 4.5,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 5.0,
#   'max': 5.0,
#   'min': 5.0,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 5.0,
#   'max': 5.0,
#   'min': 5.0,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.008680555555555554,
#   'stdev': 0.09316949906249122,
#   'avg': 4.958333333333333,
#   'max': 5.0,
#   'min': 4.75,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.03472222222222222,
#   'stdev': 0.18633899812498245,
#   'avg': 4.916666666666667,
#   'max': 5.0,
#   'min': 4.5,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.2777777777777778,
#   'stdev': 0.5270462766947299,
#   'avg': 5.25,
#   'max': 6.25,
#   'min': 4.5,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.05555555555555555,
#   'stdev': 0.23570226039551584,
#   'avg': 5.166666666666667,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 0.7098765432098765,
#   'stdev': 0.8425417160057278,
#   'avg': 5.638888888888889,
#   'max': 7.0,
#   'min': 4.75,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 5.0,
#   'max': 5.0,
#   'min': 5.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 5.0,
#   'max': 5.0,
#   'min': 5.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.22222222222222224,
#   'stdev': 0.4714045207910317,
#   'avg': 4.333333333333333,
#   'max': 5.0,
#   'min': 4.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.47222222222222227,
#   'stdev': 0.6871842709362768,
#   'avg': 4.833333333333333,
#   'max': 6.0,
#   'min': 4.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.13888888888888892,
#   'stdev': 0.372677996249965,
#   'avg': 5.166666666666667,
#   'max': 6.0,
#   'min': 5.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.046875,
#   'stdev': 0.21650635094610965,
#   'avg': 5.125,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.1528925619834711,
#   'stdev': 0.39101478486557395,
#   'avg': 4.7727272727272725,
#   'max': 5.0,
#   'min': 4.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.1728395061728395,
#   'stdev': 0.41573970964154905,
#   'avg': 5.222222222222222,
#   'max': 6.0,
#   'min': 5.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.10339506172839506,
#   'stdev': 0.32155102507750627,
#   'avg': 5.222222222222222,
#   'max': 6.0,
#   'min': 4.75,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.02469135802469136,
#   'stdev': 0.15713484026367724,
#   'avg': 4.944444444444445,
#   'max': 5.0,
#   'min': 4.5,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.10999999999999999,
#   'stdev': 0.33166247903553997,
#   'avg': 5.3,
#   'max': 5.5,
#   'min': 4.5,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.5433673469387755,
#   'stdev': 0.7371345514482248,
#   'avg': 5.535714285714286,
#   'max': 6.5,
#   'min': 4.5,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 0.02469135802469136,
#   'stdev': 0.15713484026367724,
#   'avg': 5.194444444444445,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 5.0,
#   'max': 5.0,
#   'min': 5.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q2 2016',
#   'q': 'Q2',
#   'year': '2016',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.5,
#   'max': 7.5,
#   'min': 7.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.5,
#   'max': 7.5,
#   'min': 7.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.0625,
#   'stdev': 0.25,
#   'avg': 7.25,
#   'max': 7.5,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.0,
#   'max': 7.0,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.05555555555555556,
#   'stdev': 0.23570226039551584,
#   'avg': 7.166666666666667,
#   'max': 7.5,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.5,
#   'max': 7.5,
#   'min': 7.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.0625,
#   'stdev': 0.25,
#   'avg': 7.25,
#   'max': 7.5,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.0625,
#   'stdev': 0.25,
#   'avg': 7.25,
#   'max': 7.5,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.5,
#   'stdev': 0.7071067811865476,
#   'avg': 7.0,
#   'max': 7.5,
#   'min': 6.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.5,
#   'max': 7.5,
#   'min': 7.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.03472222222222222,
#   'stdev': 0.18633899812498245,
#   'avg': 7.083333333333333,
#   'max': 7.5,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.0625,
#   'stdev': 0.25,
#   'avg': 6.75,
#   'max': 7.0,
#   'min': 6.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.1020408163265306,
#   'stdev': 0.3194382824999699,
#   'avg': 7.428571428571429,
#   'max': 8.0,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.05555555555555556,
#   'stdev': 0.23570226039551584,
#   'avg': 7.666666666666667,
#   'max': 8.0,
#   'min': 7.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.5,
#   'max': 7.5,
#   'min': 7.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 7.0,
#   'max': 7.0,
#   'min': 7.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q3 2016',
#   'q': 'Q3',
#   'year': '2016',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 5.5,
#   'max': 5.5,
#   'min': 5.5,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q4 2016',
#   'q': 'Q4',
#   'year': '2016',
#   'var': 0.05859375,
#   'stdev': 0.24206145913796356,
#   'avg': 5.1875,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.03125,
#   'stdev': 0.1767766952966369,
#   'avg': 5.125,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q2 2017',
#   'q': 'Q2',
#   'year': '2017',
#   'var': 0.03993055555555556,
#   'stdev': 0.19982631347136331,
#   'avg': 5.208333333333333,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q3 2017',
#   'q': 'Q3',
#   'year': '2017',
#   'var': 0.04644097222222223,
#   'stdev': 0.21550167568309586,
#   'avg': 5.479166666666667,
#   'max': 6.0,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q4 2017',
#   'q': 'Q4',
#   'year': '2017',
#   'var': 0.027500000000000004,
#   'stdev': 0.16583123951777,
#   'avg': 5.15,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 5.0,
#   'max': 5.0,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q2 2018',
#   'q': 'Q2',
#   'year': '2018',
#   'var': 0.0763888888888889,
#   'stdev': 0.27638539919628335,
#   'avg': 5.083333333333333,
#   'max': 5.5,
#   'min': 4.5,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q3 2018',
#   'q': 'Q3',
#   'year': '2018',
#   'var': 0.055624999999999994,
#   'stdev': 0.2358495283014151,
#   'avg': 5.275,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q4 2018',
#   'q': 'Q4',
#   'year': '2018',
#   'var': 0.06,
#   'stdev': 0.2449489742783178,
#   'avg': 5.3,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 0.046875,
#   'stdev': 0.21650635094610965,
#   'avg': 5.125,
#   'max': 5.5,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q2 2019',
#   'q': 'Q2',
#   'year': '2019',
#   'var': 0.10802469135802467,
#   'stdev': 0.32867109906108977,
#   'avg': 5.305555555555555,
#   'max': 6.0,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q3 2019',
#   'q': 'Q3',
#   'year': '2019',
#   'var': 0.1083984375,
#   'stdev': 0.32923917977664807,
#   'avg': 5.34375,
#   'max': 6.0,
#   'min': 5.0,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q4 2019',
#   'q': 'Q4',
#   'year': '2019',
#   'var': 0.05034722222222222,
#   'stdev': 0.22438186696393767,
#   'avg': 4.791666666666667,
#   'max': 5.0,
#   'min': 4.5,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')}]

# %%
# cond
for huc in conductivity_hucs:
       
    
    #checks dates for continuity and returns datecheck as boolean
    df = conductivity_df.loc[conductivity_df['HUCNAME_']==huc]
    df['datetime'] = [datetime.strptime(value, '%m/%d/%Y') for value in df['Date']]
    df = df.sort_values(by=['datetime'])
    df['datediff'] = df['datetime'].diff()
    datetimecol = df['datetime']
    min_date = min(datetimecol)
    max_date = max(datetimecol)
    diff_years = relativedelta(max_date, min_date).years
    df = df.dropna()
    datedifcol = df['datediff'].dt.days
    try:
        max_diff = max(datedifcol)
        if diff_years >=3 and max_diff <= 100:
            datecheck = True
        else:
            datecheck = False
    except:
        datecheck = False
    if datecheck == True:
#         results.append()
        #for each suitable HUC, split temps into quarters by date
        df['month'] = [int(value[0:2]) for value in df['Date']]
        df['year'] = [value[6:10] for value in df['Date']]
        df['q'] = ''
        
        df['q'].loc[df['month'] <=3] = 'Q1'
        df['q'].loc[df['month'] >=4] = 'Q2'
        df['q'].loc[df['month'] >=7] = 'Q3'
        df['q'].loc[df['month'] >=10] = 'Q4'
        
        df['Quarter'] = df['q'] + " "+ df['year']
        
        df.drop(columns = ['month', 'year'])
        
        #calculate variance or stdev of temps and avg temps for each quarter
        quarters_list = df['Quarter'].unique()    
        for quarter in quarters_list:
            quarter_df = df.loc[df['Quarter']==quarter]
            values = [value for value in quarter_df['MeasureValue']]
            variance = np.var(values)
            stdev = np.std(values)
            average = np.average(values)
            max_val = max(values)
            min_val = min(values)
            conductivity_results.append(
                {
                    'huc':huc, 
                    'quarter': quarter,
                    'q': quarter[0:2],
                    'year': quarter[3:7],
                    'var' : variance, 
                    'stdev' : stdev, 
                    'avg' : average, 
                    'max' : max_val, 
                    'min' : min_val,
                    'max_time_diff': max_diff,
                    'max_date': max_date,
                    'min_date': min_date
                }
            )
    else:
        pass

conductivity_results
# Out:
# /Users/josephgeglia/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [{'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 962.8055555555555,
#   'stdev': 31.029108197876965,
#   'avg': 268.8333333333333,
#   'max': 318.0,
#   'min': 228.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 208.88305555555556,
#   'stdev': 14.452787120675222,
#   'avg': 220.88333333333333,
#   'max': 244.0,
#   'min': 193.6,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 1060.1487603305786,
#   'stdev': 32.55992568066731,
#   'avg': 240.1818181818182,
#   'max': 291.0,
#   'min': 179.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 1606.3550472589793,
#   'stdev': 40.07935936687336,
#   'avg': 234.6130434782609,
#   'max': 295.0,
#   'min': 158.1,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Muddy Run-Susquehanna River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 777.6964,
#   'stdev': 27.887208537248757,
#   'avg': 222.14000000000001,
#   'max': 275.0,
#   'min': 185.0,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2019-07-10 00:00:00'),
#   'min_date': Timestamp('2015-05-09 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 1347.9815432098765,
#   'stdev': 36.71486814915555,
#   'avg': 231.5111111111111,
#   'max': 332.0,
#   'min': 180.5,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 950.5996587978576,
#   'stdev': 30.831796230480272,
#   'avg': 238.6450704225352,
#   'max': 343.0,
#   'min': 192.0,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 999.3899793388429,
#   'stdev': 31.61312985673584,
#   'avg': 257.70454545454544,
#   'max': 321.0,
#   'min': 202.0,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Fishing Creek-Susquehanna River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 1226.2457466918715,
#   'stdev': 35.01779185916598,
#   'avg': 256.5652173913044,
#   'max': 319.0,
#   'min': 206.0,
#   'max_time_diff': 68,
#   'max_date': Timestamp('2019-08-22 00:00:00'),
#   'min_date': Timestamp('2015-12-12 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2011',
#   'q': 'Q1',
#   'year': '2011',
#   'var': 1046965.6339374806,
#   'stdev': 1023.2133863165985,
#   'avg': 596.837501525,
#   'max': 3300.0,
#   'min': 150.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 69585.01775147929,
#   'stdev': 263.7897226039697,
#   'avg': 238.53846153846155,
#   'max': 1075.0,
#   'min': 25.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 13580.246913580248,
#   'stdev': 116.53431646335018,
#   'avg': 219.44444444444446,
#   'max': 375.0,
#   'min': 25.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 232837.42361111112,
#   'stdev': 482.5323031788764,
#   'avg': 246.83333333333334,
#   'max': 2092.0,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 1252513.592202498,
#   'stdev': 1119.1575368117296,
#   'avg': 454.5435897435897,
#   'max': 5428.0,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 52705.69898305087,
#   'stdev': 229.57721790946695,
#   'avg': 176.8,
#   'max': 800.0,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 199477.25957538298,
#   'stdev': 446.6287715490158,
#   'avg': 219.70983606557377,
#   'max': 2420.0,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 339548.6626554895,
#   'stdev': 582.7080423809933,
#   'avg': 391.01162790697674,
#   'max': 2420.0,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 143515.48544536275,
#   'stdev': 378.83437732782744,
#   'avg': 259.330303030303,
#   'max': 2419.0,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Upham Brook',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 734800.076388889,
#   'stdev': 857.2048042264398,
#   'avg': 535.9166666666666,
#   'max': 2419.0,
#   'min': 0.0,
#   'max_time_diff': 88,
#   'max_date': Timestamp('2020-06-06 00:00:00'),
#   'min_date': Timestamp('2011-03-29 00:00:00')},
#  {'huc': 'Carter Run',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 2397.572314049587,
#   'stdev': 48.96501112069298,
#   'avg': 56.13636363636363,
#   'max': 275.0,
#   'min': 20.0,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2020-06-08 00:00:00'),
#   'min_date': Timestamp('2017-02-02 00:00:00')},
#  {'huc': 'Carter Run',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 39297.09141274238,
#   'stdev': 198.23493993931135,
#   'avg': 135.52631578947367,
#   'max': 1050.0,
#   'min': 25.0,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2020-06-08 00:00:00'),
#   'min_date': Timestamp('2017-02-02 00:00:00')},
#  {'huc': 'Carter Run',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 27231.221075115696,
#   'stdev': 165.0188506659639,
#   'avg': 138.20754716981133,
#   'max': 675.0,
#   'min': 25.0,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2020-06-08 00:00:00'),
#   'min_date': Timestamp('2017-02-02 00:00:00')},
#  {'huc': 'Carter Run',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 6270.1388888888905,
#   'stdev': 79.1842085828285,
#   'avg': 75.83333333333333,
#   'max': 325.0,
#   'min': 25.0,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2020-06-08 00:00:00'),
#   'min_date': Timestamp('2017-02-02 00:00:00')},
#  {'huc': 'Stony Run-South River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 420.25,
#   'stdev': 20.5,
#   'avg': 394.5,
#   'max': 415.0,
#   'min': 374.0,
#   'max_time_diff': 78,
#   'max_date': Timestamp('2019-12-02 00:00:00'),
#   'min_date': Timestamp('2016-10-11 00:00:00')},
#  {'huc': 'Stony Run-South River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 15013.819669421484,
#   'stdev': 122.53089271453744,
#   'avg': 364.8181818181818,
#   'max': 476.0,
#   'min': 44.3,
#   'max_time_diff': 78,
#   'max_date': Timestamp('2019-12-02 00:00:00'),
#   'min_date': Timestamp('2016-10-11 00:00:00')},
#  {'huc': 'Stony Run-South River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 6655.289999999999,
#   'stdev': 81.57996077469025,
#   'avg': 365.9,
#   'max': 458.0,
#   'min': 230.0,
#   'max_time_diff': 78,
#   'max_date': Timestamp('2019-12-02 00:00:00'),
#   'min_date': Timestamp('2016-10-11 00:00:00')},
#  {'huc': 'Stony Run-South River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 22771.107438016534,
#   'stdev': 150.90098554355612,
#   'avg': 252.27272727272728,
#   'max': 462.0,
#   'min': 0.0,
#   'max_time_diff': 78,
#   'max_date': Timestamp('2019-12-02 00:00:00'),
#   'min_date': Timestamp('2016-10-11 00:00:00')},
#  {'huc': 'Parks Creek-Susquehanna River',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 2644.25,
#   'stdev': 51.422271439523165,
#   'avg': 293.0,
#   'max': 392.0,
#   'min': 191.0,
#   'max_time_diff': 55,
#   'max_date': Timestamp('2018-05-15 00:00:00'),
#   'min_date': Timestamp('2015-04-16 00:00:00')},
#  {'huc': 'Parks Creek-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 3204.5725925925926,
#   'stdev': 56.60894445750241,
#   'avg': 237.03333333333336,
#   'max': 365.0,
#   'min': 159.2,
#   'max_time_diff': 55,
#   'max_date': Timestamp('2018-05-15 00:00:00'),
#   'min_date': Timestamp('2015-04-16 00:00:00')},
#  {'huc': 'Parks Creek-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 1072.780864,
#   'stdev': 32.75333363186105,
#   'avg': 175.55599999999998,
#   'max': 252.0,
#   'min': 127.2,
#   'max_time_diff': 55,
#   'max_date': Timestamp('2018-05-15 00:00:00'),
#   'min_date': Timestamp('2015-04-16 00:00:00')},
#  {'huc': 'Parks Creek-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 1055.2684,
#   'stdev': 32.484894951346234,
#   'avg': 177.06,
#   'max': 237.0,
#   'min': 136.0,
#   'max_time_diff': 55,
#   'max_date': Timestamp('2018-05-15 00:00:00'),
#   'min_date': Timestamp('2015-04-16 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 4110.973333333332,
#   'stdev': 64.11687245439637,
#   'avg': 258.56666666666666,
#   'max': 412.0,
#   'min': 137.9,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 4309.7451872257925,
#   'stdev': 65.64864954609342,
#   'avg': 215.20808080808078,
#   'max': 368.0,
#   'min': 79.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 5655.638200183655,
#   'stdev': 75.20397728965972,
#   'avg': 218.75757575757575,
#   'max': 376.0,
#   'min': 105.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 4981.893333333334,
#   'stdev': 70.5825285274857,
#   'avg': 239.8,
#   'max': 373.0,
#   'min': 125.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 3077.3541666666665,
#   'stdev': 55.473905276865686,
#   'avg': 276.75,
#   'max': 356.0,
#   'min': 207.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 1875.7430555555559,
#   'stdev': 43.30984940582864,
#   'avg': 211.41666666666666,
#   'max': 299.0,
#   'min': 143.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 3645.9097222222226,
#   'stdev': 60.38136899923869,
#   'avg': 191.08333333333334,
#   'max': 300.0,
#   'min': 108.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Lower Nanticoke Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 1363.7430555555557,
#   'stdev': 36.92889188095895,
#   'avg': 220.58333333333334,
#   'max': 289.0,
#   'min': 172.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-08-09 00:00:00')},
#  {'huc': 'Upper Canacadea Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 51677.77769322235,
#   'stdev': 227.32746796905636,
#   'avg': 490.8758620689655,
#   'max': 856.0,
#   'min': 128.6,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-09-23 00:00:00')},
#  {'huc': 'Upper Canacadea Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 50321.77871320265,
#   'stdev': 224.3251629068898,
#   'avg': 512.9677685950413,
#   'max': 1169.0,
#   'min': 141.7,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-09-23 00:00:00')},
#  {'huc': 'Upper Canacadea Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 97438.13227875753,
#   'stdev': 312.15081655949183,
#   'avg': 487.9328467153285,
#   'max': 2950.0,
#   'min': 120.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-09-23 00:00:00')},
#  {'huc': 'Upper Canacadea Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 109980.589475,
#   'stdev': 331.63321527705875,
#   'avg': 627.2549999999999,
#   'max': 1198.0,
#   'min': 148.7,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-09-23 00:00:00')},
#  {'huc': 'Upper Canacadea Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 83985.17355371901,
#   'stdev': 289.80195574515886,
#   'avg': 762.9090909090909,
#   'max': 1266.0,
#   'min': 380.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-09-23 00:00:00')},
#  {'huc': 'Upper Canacadea Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 542.0,
#   'max': 542.0,
#   'min': 542.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-09-23 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 9398.78945179584,
#   'stdev': 96.94735402163299,
#   'avg': 342.95217391304345,
#   'max': 509.0,
#   'min': 176.9,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 1888.5644748263887,
#   'stdev': 43.45761699433586,
#   'avg': 234.83958333333337,
#   'max': 361.0,
#   'min': 124.6,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 6235.32770661157,
#   'stdev': 78.96409124793098,
#   'avg': 260.50454545454545,
#   'max': 466.0,
#   'min': 129.1,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 7089.313609467455,
#   'stdev': 84.19806179163184,
#   'avg': 289.61538461538464,
#   'max': 473.0,
#   'min': 177.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 6617.333333333333,
#   'stdev': 81.34699338840578,
#   'avg': 321.0,
#   'max': 477.0,
#   'min': 213.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 3575.909722222222,
#   'stdev': 59.7989107110006,
#   'avg': 267.5833333333333,
#   'max': 414.0,
#   'min': 192.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 4127.409722222222,
#   'stdev': 64.24491981645103,
#   'avg': 239.58333333333334,
#   'max': 348.0,
#   'min': 134.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Patterson Creek-Susquehanna River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 4822.909722222223,
#   'stdev': 69.44717216865078,
#   'avg': 273.0833333333333,
#   'max': 407.0,
#   'min': 192.0,
#   'max_time_diff': 60,
#   'max_date': Timestamp('2019-12-30 00:00:00'),
#   'min_date': Timestamp('2012-07-13 00:00:00')},
#  {'huc': 'Karr Valley Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 18881.055555555555,
#   'stdev': 137.40835329613537,
#   'avg': 374.6666666666667,
#   'max': 615.0,
#   'min': 175.0,
#   'max_time_diff': 84,
#   'max_date': Timestamp('2017-04-23 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'Karr Valley Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 27277.057119113575,
#   'stdev': 165.15767350963011,
#   'avg': 327.9842105263158,
#   'max': 665.0,
#   'min': 112.0,
#   'max_time_diff': 84,
#   'max_date': Timestamp('2017-04-23 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'Karr Valley Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 29252.59408304498,
#   'stdev': 171.03389746785572,
#   'avg': 276.3058823529412,
#   'max': 653.0,
#   'min': 63.6,
#   'max_time_diff': 84,
#   'max_date': Timestamp('2017-04-23 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'Karr Valley Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 36129.06171597633,
#   'stdev': 190.07646281424832,
#   'avg': 320.6461538461538,
#   'max': 675.0,
#   'min': 55.5,
#   'max_time_diff': 84,
#   'max_date': Timestamp('2017-04-23 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'Karr Valley Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 5695.402222222223,
#   'stdev': 75.46788868268558,
#   'avg': 163.53333333333333,
#   'max': 243.0,
#   'min': 62.1,
#   'max_time_diff': 84,
#   'max_date': Timestamp('2017-04-23 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'McHenry Valley Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 12370.083333333334,
#   'stdev': 111.22087633773317,
#   'avg': 303.5,
#   'max': 488.0,
#   'min': 132.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'McHenry Valley Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 10365.173553719007,
#   'stdev': 101.80949638279823,
#   'avg': 312.09090909090907,
#   'max': 473.0,
#   'min': 132.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'McHenry Valley Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 14002.793388429754,
#   'stdev': 118.33339929381626,
#   'avg': 307.54545454545456,
#   'max': 488.0,
#   'min': 135.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'McHenry Valley Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 11430.611570247933,
#   'stdev': 106.91403822813884,
#   'avg': 307.54545454545456,
#   'max': 483.0,
#   'min': 192.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'McHenry Valley Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 188.0,
#   'max': 188.0,
#   'min': 188.0,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2017-01-29 00:00:00'),
#   'min_date': Timestamp('2012-12-01 00:00:00')},
#  {'huc': 'Goff Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 59666.8888888889,
#   'stdev': 244.26806768157172,
#   'avg': 529.6666666666666,
#   'max': 754.0,
#   'min': 190.0,
#   'max_time_diff': 65,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Goff Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 9636.316608996538,
#   'stdev': 98.16474218881511,
#   'avg': 292.8529411764706,
#   'max': 484.0,
#   'min': 161.5,
#   'max_time_diff': 65,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Goff Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 29838.65759637188,
#   'stdev': 172.7386974489847,
#   'avg': 344.26190476190476,
#   'max': 690.0,
#   'min': 162.0,
#   'max_time_diff': 65,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Goff Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 8319.471074380166,
#   'stdev': 91.21113459649631,
#   'avg': 230.27272727272728,
#   'max': 389.0,
#   'min': 112.0,
#   'max_time_diff': 65,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2011',
#   'q': 'Q1',
#   'year': '2011',
#   'var': 3200.633609693878,
#   'stdev': 56.5741425891182,
#   'avg': 93.98214285714286,
#   'max': 316.0,
#   'min': 24.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 6125.760802469136,
#   'stdev': 78.26723965024662,
#   'avg': 138.05555555555554,
#   'max': 302.0,
#   'min': 35.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 3441.048583984375,
#   'stdev': 58.66045161763056,
#   'avg': 134.421875,
#   'max': 304.0,
#   'min': 62.5,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 1991.5044378698224,
#   'stdev': 44.62627519600782,
#   'avg': 126.73076923076923,
#   'max': 283.0,
#   'min': 57.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 795.2006172839506,
#   'stdev': 28.199301716247348,
#   'avg': 124.27777777777777,
#   'max': 168.0,
#   'min': 82.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 786.4375,
#   'stdev': 28.0434930063999,
#   'avg': 106.75,
#   'max': 166.0,
#   'min': 69.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 2527.5691609977325,
#   'stdev': 50.27493571351168,
#   'avg': 114.38095238095238,
#   'max': 308.0,
#   'min': 64.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 467.2760416666667,
#   'stdev': 21.61656868392083,
#   'avg': 94.875,
#   'max': 148.0,
#   'min': 59.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 348.24376731301936,
#   'stdev': 18.66129061220095,
#   'avg': 100.42105263157895,
#   'max': 143.0,
#   'min': 77.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Upper Cayuta Creek',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 350.1875,
#   'stdev': 18.713297411199342,
#   'avg': 106.25,
#   'max': 131.0,
#   'min': 80.0,
#   'max_time_diff': 99,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-02-06 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2011',
#   'q': 'Q1',
#   'year': '2011',
#   'var': 3314.6066666666666,
#   'stdev': 57.57262080769527,
#   'avg': 187.1,
#   'max': 351.0,
#   'min': 130.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 4821.15234375,
#   'stdev': 69.4345183878307,
#   'avg': 212.4375,
#   'max': 396.0,
#   'min': 120.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 3906.9528061224487,
#   'stdev': 62.50562219610688,
#   'avg': 203.60714285714286,
#   'max': 362.0,
#   'min': 111.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 3729.9071980963713,
#   'stdev': 61.07296618059721,
#   'avg': 225.46341463414635,
#   'max': 373.0,
#   'min': 91.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 6371.5392536506215,
#   'stdev': 79.8219221370334,
#   'avg': 244.49302325581397,
#   'max': 408.0,
#   'min': 3.2,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 6039.9710884353735,
#   'stdev': 77.71725090631664,
#   'avg': 250.92857142857142,
#   'max': 459.0,
#   'min': 143.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 4921.418367346939,
#   'stdev': 70.1528215209263,
#   'avg': 212.28571428571428,
#   'max': 378.0,
#   'min': 131.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 939.7482638888888,
#   'stdev': 30.655313795309432,
#   'avg': 180.54166666666666,
#   'max': 232.0,
#   'min': 103.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 2399.9445983379496,
#   'stdev': 48.98922941155484,
#   'avg': 195.05263157894737,
#   'max': 386.0,
#   'min': 146.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Headwaters Cayuta Creek',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 398.5,
#   'stdev': 19.96246477767713,
#   'avg': 171.0,
#   'max': 190.0,
#   'min': 140.0,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2020-02-23 00:00:00'),
#   'min_date': Timestamp('2011-03-08 00:00:00')},
#  {'huc': 'Middle Canisteo River',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 20890.5,
#   'stdev': 144.53546277644114,
#   'avg': 405.0,
#   'max': 550.0,
#   'min': 199.0,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Middle Canisteo River',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 26179.86858024692,
#   'stdev': 161.8019424489302,
#   'avg': 324.24444444444447,
#   'max': 716.0,
#   'min': 100.0,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Middle Canisteo River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 23009.694438775514,
#   'stdev': 151.6894671319519,
#   'avg': 356.0357142857143,
#   'max': 625.0,
#   'min': 112.2,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Middle Canisteo River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 17965.356875000005,
#   'stdev': 134.03490916548571,
#   'avg': 342.675,
#   'max': 527.0,
#   'min': 134.0,
#   'max_time_diff': 66,
#   'max_date': Timestamp('2017-11-12 00:00:00'),
#   'min_date': Timestamp('2014-11-04 00:00:00')},
#  {'huc': 'Headwaters Cowanesque River',
#   'quarter': 'Q1 2011',
#   'q': 'Q1',
#   'year': '2011',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 63.0,
#   'max': 63.0,
#   'min': 63.0,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-11-11 00:00:00'),
#   'min_date': Timestamp('2011-10-21 00:00:00')},
#  {'huc': 'Headwaters Cowanesque River',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 844.2191380569759,
#   'stdev': 29.055449369386388,
#   'avg': 115.32432432432432,
#   'max': 187.0,
#   'min': 70.0,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-11-11 00:00:00'),
#   'min_date': Timestamp('2011-10-21 00:00:00')},
#  {'huc': 'Headwaters Cowanesque River',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 1777.4466759002771,
#   'stdev': 42.159775567479926,
#   'avg': 117.02631578947368,
#   'max': 247.0,
#   'min': 62.0,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-11-11 00:00:00'),
#   'min_date': Timestamp('2011-10-21 00:00:00')},
#  {'huc': 'Headwaters Cowanesque River',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 451.0256198347108,
#   'stdev': 21.23736376847915,
#   'avg': 98.22727272727273,
#   'max': 130.0,
#   'min': 61.8,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-11-11 00:00:00'),
#   'min_date': Timestamp('2011-10-21 00:00:00')},
#  {'huc': 'Sixmile Run',
#   'quarter': 'Q1 2011',
#   'q': 'Q1',
#   'year': '2011',
#   'var': 77.44378698224851,
#   'stdev': 8.800215166815441,
#   'avg': 53.30769230769231,
#   'max': 69.0,
#   'min': 44.0,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-08-03 00:00:00'),
#   'min_date': Timestamp('2011-06-29 00:00:00')},
#  {'huc': 'Sixmile Run',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 818.5540166204985,
#   'stdev': 28.610383021212744,
#   'avg': 70.84210526315789,
#   'max': 143.0,
#   'min': 42.0,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-08-03 00:00:00'),
#   'min_date': Timestamp('2011-06-29 00:00:00')},
#  {'huc': 'Sixmile Run',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 420.91609977324265,
#   'stdev': 20.516239903384896,
#   'avg': 64.80952380952381,
#   'max': 130.0,
#   'min': 43.0,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-08-03 00:00:00'),
#   'min_date': Timestamp('2011-06-29 00:00:00')},
#  {'huc': 'Sixmile Run',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 558.1730103806229,
#   'stdev': 23.625685394938767,
#   'avg': 65.94117647058823,
#   'max': 138.0,
#   'min': 43.0,
#   'max_time_diff': 85,
#   'max_date': Timestamp('2014-08-03 00:00:00'),
#   'min_date': Timestamp('2011-06-29 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 761.80859375,
#   'stdev': 27.60088030751918,
#   'avg': 118.9375,
#   'max': 181.0,
#   'min': 87.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 8011.05,
#   'stdev': 89.50446916215972,
#   'avg': 122.5,
#   'max': 498.0,
#   'min': 74.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 7558.535714285715,
#   'stdev': 86.939839626524,
#   'avg': 101.5,
#   'max': 412.0,
#   'min': 58.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 521.2430555555555,
#   'stdev': 22.830748028821912,
#   'avg': 79.41666666666667,
#   'max': 134.0,
#   'min': 59.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 206.99555555555557,
#   'stdev': 14.387340113987559,
#   'avg': 88.26666666666667,
#   'max': 110.0,
#   'min': 63.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 206.91666666666666,
#   'stdev': 14.38459824488215,
#   'avg': 69.5,
#   'max': 105.0,
#   'min': 53.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 470.3801652892562,
#   'stdev': 21.68824947498659,
#   'avg': 80.27272727272727,
#   'max': 112.0,
#   'min': 51.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Laurel Run-Bald Eagle Creek',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 84.0,
#   'max': 84.0,
#   'min': 84.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2013-04-11 00:00:00')},
#  {'huc': 'Wallace Run',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 2689.1875,
#   'stdev': 51.85737652446371,
#   'avg': 108.75,
#   'max': 197.0,
#   'min': 70.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2015-09-01 00:00:00')},
#  {'huc': 'Wallace Run',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 4254.284023668639,
#   'stdev': 65.22487273784931,
#   'avg': 110.15384615384616,
#   'max': 294.0,
#   'min': 63.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2015-09-01 00:00:00')},
#  {'huc': 'Wallace Run',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 4432.062222222222,
#   'stdev': 66.57373522810795,
#   'avg': 132.93333333333334,
#   'max': 312.0,
#   'min': 73.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2015-09-01 00:00:00')},
#  {'huc': 'Wallace Run',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 100.1388888888889,
#   'stdev': 10.00694203485205,
#   'avg': 77.16666666666667,
#   'max': 104.0,
#   'min': 67.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2015-09-01 00:00:00')},
#  {'huc': 'Wallace Run',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 2637.719008264463,
#   'stdev': 51.35872864727536,
#   'avg': 128.9090909090909,
#   'max': 216.0,
#   'min': 72.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2015-09-01 00:00:00')},
#  {'huc': 'Wallace Run',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 94.0,
#   'max': 94.0,
#   'min': 94.0,
#   'max_time_diff': 61,
#   'max_date': Timestamp('2020-01-05 00:00:00'),
#   'min_date': Timestamp('2015-09-01 00:00:00')},
#  {'huc': 'Bailey Creek-Mill Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 1468.4612476370512,
#   'stdev': 38.32050688126465,
#   'avg': 185.8695652173913,
#   'max': 231.0,
#   'min': 84.0,
#   'max_time_diff': 71,
#   'max_date': Timestamp('2017-04-09 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Bailey Creek-Mill Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 1996.5270672218915,
#   'stdev': 44.68251411035296,
#   'avg': 162.09756097560975,
#   'max': 232.0,
#   'min': 92.0,
#   'max_time_diff': 71,
#   'max_date': Timestamp('2017-04-09 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Bailey Creek-Mill Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 3045.044897959184,
#   'stdev': 55.18192546440532,
#   'avg': 186.57142857142858,
#   'max': 279.0,
#   'min': 91.0,
#   'max_time_diff': 71,
#   'max_date': Timestamp('2017-04-09 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Bailey Creek-Mill Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 2642.463010204082,
#   'stdev': 51.404892862490065,
#   'avg': 178.96428571428572,
#   'max': 268.0,
#   'min': 98.0,
#   'max_time_diff': 71,
#   'max_date': Timestamp('2017-04-09 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Bailey Creek-Mill Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 3887.473214285714,
#   'stdev': 62.349604764470755,
#   'avg': 195.25,
#   'max': 290.0,
#   'min': 84.0,
#   'max_time_diff': 71,
#   'max_date': Timestamp('2017-04-09 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Bailey Creek-Mill Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 525.8367346938775,
#   'stdev': 22.93113025330146,
#   'avg': 107.14285714285714,
#   'max': 149.0,
#   'min': 83.0,
#   'max_time_diff': 71,
#   'max_date': Timestamp('2017-04-09 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Gaffers Creek-Elk Run',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 1465.0359168241969,
#   'stdev': 38.275787605537225,
#   'avg': 220.91304347826087,
#   'max': 278.0,
#   'min': 121.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Gaffers Creek-Elk Run',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 2973.509815585961,
#   'stdev': 54.52989836397975,
#   'avg': 208.9512195121951,
#   'max': 298.0,
#   'min': 119.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Gaffers Creek-Elk Run',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 3760.5142332415057,
#   'stdev': 61.32303183341073,
#   'avg': 226.03030303030303,
#   'max': 316.0,
#   'min': 122.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Gaffers Creek-Elk Run',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 1975.3151010701547,
#   'stdev': 44.44451710920206,
#   'avg': 234.82758620689654,
#   'max': 310.0,
#   'min': 147.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Gaffers Creek-Elk Run',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 4595.316326530612,
#   'stdev': 67.78876253871738,
#   'avg': 242.42857142857142,
#   'max': 342.0,
#   'min': 126.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Gaffers Creek-Elk Run',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 1941.5371900826447,
#   'stdev': 44.06287768726238,
#   'avg': 161.9090909090909,
#   'max': 237.0,
#   'min': 112.0,
#   'max_time_diff': 56,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-06-11 00:00:00')},
#  {'huc': 'Painter Run-Mill Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 3294.0355998576006,
#   'stdev': 57.39368954735007,
#   'avg': 164.66037735849056,
#   'max': 266.0,
#   'min': 50.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-05-14 00:00:00')},
#  {'huc': 'Painter Run-Mill Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 4597.121882086169,
#   'stdev': 67.80207874457957,
#   'avg': 147.73809523809524,
#   'max': 272.0,
#   'min': 50.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-05-14 00:00:00')},
#  {'huc': 'Painter Run-Mill Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 6049.357050173011,
#   'stdev': 77.77761278268324,
#   'avg': 166.60294117647058,
#   'max': 318.0,
#   'min': 36.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-05-14 00:00:00')},
#  {'huc': 'Painter Run-Mill Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 5237.6599286563605,
#   'stdev': 72.37167905096828,
#   'avg': 165.82758620689654,
#   'max': 303.0,
#   'min': 49.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-05-14 00:00:00')},
#  {'huc': 'Painter Run-Mill Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 6392.106823979592,
#   'stdev': 79.95065242998078,
#   'avg': 173.76785714285714,
#   'max': 316.0,
#   'min': 48.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-05-14 00:00:00')},
#  {'huc': 'Painter Run-Mill Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 3516.049586776859,
#   'stdev': 59.29628645013833,
#   'avg': 111.63636363636364,
#   'max': 224.0,
#   'min': 42.0,
#   'max_time_diff': 37,
#   'max_date': Timestamp('2017-06-26 00:00:00'),
#   'min_date': Timestamp('2012-05-14 00:00:00')},
#  {'huc': 'Upper Kettle Creek',
#   'quarter': 'Q1 2012',
#   'q': 'Q1',
#   'year': '2012',
#   'var': 18953.40868530636,
#   'stdev': 137.67137932521183,
#   'avg': 147.390243902439,
#   'max': 970.0,
#   'min': 39.0,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2017-12-20 00:00:00'),
#   'min_date': Timestamp('2012-04-02 00:00:00')},
#  {'huc': 'Upper Kettle Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 534.059917355372,
#   'stdev': 23.10973641899388,
#   'avg': 126.5909090909091,
#   'max': 169.0,
#   'min': 90.0,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2017-12-20 00:00:00'),
#   'min_date': Timestamp('2012-04-02 00:00:00')},
#  {'huc': 'Upper Kettle Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 3320.004997917534,
#   'stdev': 57.619484533597955,
#   'avg': 113.48979591836735,
#   'max': 390.0,
#   'min': 36.0,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2017-12-20 00:00:00'),
#   'min_date': Timestamp('2012-04-02 00:00:00')},
#  {'huc': 'Upper Kettle Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 3042.650519031142,
#   'stdev': 55.16022587908014,
#   'avg': 80.76470588235294,
#   'max': 238.0,
#   'min': 32.0,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2017-12-20 00:00:00'),
#   'min_date': Timestamp('2012-04-02 00:00:00')},
#  {'huc': 'Upper Kettle Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 88.41,
#   'stdev': 9.402659198333204,
#   'avg': 45.7,
#   'max': 59.0,
#   'min': 32.0,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2017-12-20 00:00:00'),
#   'min_date': Timestamp('2012-04-02 00:00:00')},
#  {'huc': 'Upper Kettle Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 85.5763888888889,
#   'stdev': 9.250750720286916,
#   'avg': 41.416666666666664,
#   'max': 58.0,
#   'min': 30.0,
#   'max_time_diff': 59,
#   'max_date': Timestamp('2017-12-20 00:00:00'),
#   'min_date': Timestamp('2012-04-02 00:00:00')},
#  {'huc': 'Letort Spring Run',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 4523.014865205342,
#   'stdev': 67.25336322597809,
#   'avg': 611.2539682539683,
#   'max': 822.0,
#   'min': 462.0,
#   'max_time_diff': 51,
#   'max_date': Timestamp('2020-06-24 00:00:00'),
#   'min_date': Timestamp('2017-04-12 00:00:00')},
#  {'huc': 'Letort Spring Run',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 6593.4643595041325,
#   'stdev': 81.2001499968081,
#   'avg': 628.6136363636364,
#   'max': 873.0,
#   'min': 469.0,
#   'max_time_diff': 51,
#   'max_date': Timestamp('2020-06-24 00:00:00'),
#   'min_date': Timestamp('2017-04-12 00:00:00')},
#  {'huc': 'Letort Spring Run',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 6996.286694101509,
#   'stdev': 83.64380846244096,
#   'avg': 622.4814814814815,
#   'max': 1152.0,
#   'min': 548.0,
#   'max_time_diff': 51,
#   'max_date': Timestamp('2020-06-24 00:00:00'),
#   'min_date': Timestamp('2017-04-12 00:00:00')},
#  {'huc': 'Letort Spring Run',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 1840.5603807257587,
#   'stdev': 42.901752653309615,
#   'avg': 603.0243902439024,
#   'max': 692.0,
#   'min': 540.0,
#   'max_time_diff': 51,
#   'max_date': Timestamp('2020-06-24 00:00:00'),
#   'min_date': Timestamp('2017-04-12 00:00:00')},
#  {'huc': 'Little Clearfield Creek',
#   'quarter': 'Q1 2013',
#   'q': 'Q1',
#   'year': '2013',
#   'var': 69638.77963688146,
#   'stdev': 263.89160584770684,
#   'avg': 636.1132075471698,
#   'max': 1382.0,
#   'min': 256.0,
#   'max_time_diff': 89,
#   'max_date': Timestamp('2019-12-21 00:00:00'),
#   'min_date': Timestamp('2013-07-23 00:00:00')},
#  {'huc': 'Little Clearfield Creek',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 39379.684375,
#   'stdev': 198.44315149432595,
#   'avg': 482.375,
#   'max': 1255.0,
#   'min': 148.0,
#   'max_time_diff': 89,
#   'max_date': Timestamp('2019-12-21 00:00:00'),
#   'min_date': Timestamp('2013-07-23 00:00:00')},
#  {'huc': 'Little Clearfield Creek',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 34080.48526230395,
#   'stdev': 184.60900644958778,
#   'avg': 460.7093023255814,
#   'max': 1174.0,
#   'min': 103.0,
#   'max_time_diff': 89,
#   'max_date': Timestamp('2019-12-21 00:00:00'),
#   'min_date': Timestamp('2013-07-23 00:00:00')},
#  {'huc': 'Little Clearfield Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 24797.54654702772,
#   'stdev': 157.47236756659157,
#   'avg': 479.1518987341772,
#   'max': 966.0,
#   'min': 148.0,
#   'max_time_diff': 89,
#   'max_date': Timestamp('2019-12-21 00:00:00'),
#   'min_date': Timestamp('2013-07-23 00:00:00')},
#  {'huc': 'Little Clearfield Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 22050.34917091837,
#   'stdev': 148.49359976415943,
#   'avg': 420.1607142857143,
#   'max': 1187.0,
#   'min': 191.0,
#   'max_time_diff': 89,
#   'max_date': Timestamp('2019-12-21 00:00:00'),
#   'min_date': Timestamp('2013-07-23 00:00:00')},
#  {'huc': 'Little Clearfield Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 12536.353806228375,
#   'stdev': 111.96586000307583,
#   'avg': 392.61764705882354,
#   'max': 638.0,
#   'min': 168.0,
#   'max_time_diff': 89,
#   'max_date': Timestamp('2019-12-21 00:00:00'),
#   'min_date': Timestamp('2013-07-23 00:00:00')},
#  {'huc': 'Little Clearfield Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 124363.58693877552,
#   'stdev': 352.65221811123706,
# ...
#   'max': 132.7,
#   'min': 19.85,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2012-06-30 00:00:00')},
#  {'huc': 'Cabin Creek-Mill Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 11895.45443877551,
#   'stdev': 109.06628461066926,
#   'avg': 131.93571428571428,
#   'max': 408.0,
#   'min': 30.35,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2012-06-30 00:00:00')},
#  {'huc': 'Cabin Creek-Mill Creek',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 1120.5756250000002,
#   'stdev': 33.475,
#   'avg': 78.225,
#   'max': 111.7,
#   'min': 44.75,
#   'max_time_diff': 91,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2012-06-30 00:00:00')},
#  {'huc': 'Ramseys Draft',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 11.055624999999996,
#   'stdev': 3.3249999999999993,
#   'avg': 24.925,
#   'max': 28.25,
#   'min': 21.6,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2019-03-27 00:00:00'),
#   'min_date': Timestamp('2014-10-21 00:00:00')},
#  {'huc': 'Ramseys Draft',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 186.9807780612245,
#   'stdev': 13.674091489427168,
#   'avg': 33.93928571428571,
#   'max': 60.1,
#   'min': 16.25,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2019-03-27 00:00:00'),
#   'min_date': Timestamp('2014-10-21 00:00:00')},
#  {'huc': 'Ramseys Draft',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 118.75163553719004,
#   'stdev': 10.897322402186237,
#   'avg': 46.7890909090909,
#   'max': 70.5,
#   'min': 32.65,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2019-03-27 00:00:00'),
#   'min_date': Timestamp('2014-10-21 00:00:00')},
#  {'huc': 'Ramseys Draft',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 169.2241557669441,
#   'stdev': 13.008618518772241,
#   'avg': 47.31551724137931,
#   'max': 76.1,
#   'min': 24.2,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2019-03-27 00:00:00'),
#   'min_date': Timestamp('2014-10-21 00:00:00')},
#  {'huc': 'Ramseys Draft',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 74.97472499999999,
#   'stdev': 8.65879466207624,
#   'avg': 34.404999999999994,
#   'max': 55.2,
#   'min': 21.65,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2019-03-27 00:00:00'),
#   'min_date': Timestamp('2014-10-21 00:00:00')},
#  {'huc': 'Ramseys Draft',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 66.7422916666667,
#   'stdev': 8.169595563225068,
#   'avg': 31.674999999999997,
#   'max': 45.7,
#   'min': 21.55,
#   'max_time_diff': 73,
#   'max_date': Timestamp('2019-03-27 00:00:00'),
#   'min_date': Timestamp('2014-10-21 00:00:00')},
#  {'huc': 'Inch Branch-Back Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 722.3700623039481,
#   'stdev': 26.876942949374804,
#   'avg': 42.41069767441859,
#   'max': 99.6,
#   'min': 6.8,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2015-12-20 00:00:00')},
#  {'huc': 'Inch Branch-Back Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 804.2343742028061,
#   'stdev': 28.35902632677656,
#   'avg': 51.72589285714285,
#   'max': 135.2,
#   'min': 8.9,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2015-12-20 00:00:00')},
#  {'huc': 'Inch Branch-Back Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 445.34749411764705,
#   'stdev': 21.10325790293165,
#   'avg': 35.19,
#   'max': 94.3,
#   'min': 8.5,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2015-12-20 00:00:00')},
#  {'huc': 'Inch Branch-Back Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 863.6657475994514,
#   'stdev': 29.388190614589586,
#   'avg': 48.30925925925926,
#   'max': 124.4,
#   'min': 7.6,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2015-12-20 00:00:00')},
#  {'huc': 'Inch Branch-Back Creek',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 802.5491666666668,
#   'stdev': 28.32929873234893,
#   'avg': 43.1,
#   'max': 93.4,
#   'min': 11.4,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2015-12-20 00:00:00')},
#  {'huc': 'Canada Run-South River',
#   'quarter': 'Q1 2014',
#   'q': 'Q1',
#   'year': '2014',
#   'var': 1.322500000000001,
#   'stdev': 1.1500000000000004,
#   'avg': 12.35,
#   'max': 13.5,
#   'min': 11.2,
#   'max_time_diff': 72,
#   'max_date': Timestamp('2020-01-06 00:00:00'),
#   'min_date': Timestamp('2014-09-14 00:00:00')},
#  {'huc': 'Canada Run-South River',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 14.88913580246913,
#   'stdev': 3.8586442959242993,
#   'avg': 11.944444444444445,
#   'max': 20.4,
#   'min': 6.4,
#   'max_time_diff': 72,
#   'max_date': Timestamp('2020-01-06 00:00:00'),
#   'min_date': Timestamp('2014-09-14 00:00:00')},
#  {'huc': 'Canada Run-South River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 39344.7929,
#   'stdev': 198.35521898856103,
#   'avg': 170.81,
#   'max': 461.0,
#   'min': 8.0,
#   'max_time_diff': 72,
#   'max_date': Timestamp('2020-01-06 00:00:00'),
#   'min_date': Timestamp('2014-09-14 00:00:00')},
#  {'huc': 'Canada Run-South River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 35336.457599999994,
#   'stdev': 187.97993935524076,
#   'avg': 308.68,
#   'max': 509.0,
#   'min': 7.5,
#   'max_time_diff': 72,
#   'max_date': Timestamp('2020-01-06 00:00:00'),
#   'min_date': Timestamp('2014-09-14 00:00:00')},
#  {'huc': 'Canada Run-South River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 8559.34023668639,
#   'stdev': 92.51670247412837,
#   'avg': 221.22307692307697,
#   'max': 402.0,
#   'min': 90.3,
#   'max_time_diff': 72,
#   'max_date': Timestamp('2020-01-06 00:00:00'),
#   'min_date': Timestamp('2014-09-14 00:00:00')},
#  {'huc': 'Canada Run-South River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 14817.395763888888,
#   'stdev': 121.7267257585157,
#   'avg': 300.0416666666667,
#   'max': 445.0,
#   'min': 104.1,
#   'max_time_diff': 72,
#   'max_date': Timestamp('2020-01-06 00:00:00'),
#   'min_date': Timestamp('2014-09-14 00:00:00')},
#  {'huc': 'Canada Run-South River',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 402.0,
#   'max': 402.0,
#   'min': 402.0,
#   'max_time_diff': 72,
#   'max_date': Timestamp('2020-01-06 00:00:00'),
#   'min_date': Timestamp('2014-09-14 00:00:00')},
#  {'huc': 'Chair Draft-Calfpasture River',
#   'quarter': 'Q1 2015',
#   'q': 'Q1',
#   'year': '2015',
#   'var': 39.997968750000005,
#   'stdev': 6.324394733885607,
#   'avg': 38.7875,
#   'max': 48.0,
#   'min': 31.5,
#   'max_time_diff': 70,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2015-09-05 00:00:00')},
#  {'huc': 'Chair Draft-Calfpasture River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 980.1906632653062,
#   'stdev': 31.307996794194707,
#   'avg': 52.142857142857146,
#   'max': 149.4,
#   'min': 25.0,
#   'max_time_diff': 70,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2015-09-05 00:00:00')},
#  {'huc': 'Chair Draft-Calfpasture River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 465.87044378698215,
#   'stdev': 21.584032148488433,
#   'avg': 45.96153846153846,
#   'max': 125.8,
#   'min': 24.5,
#   'max_time_diff': 70,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2015-09-05 00:00:00')},
#  {'huc': 'Chair Draft-Calfpasture River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 458.4878344671202,
#   'stdev': 21.412329029489534,
#   'avg': 40.60476190476191,
#   'max': 106.8,
#   'min': 12.95,
#   'max_time_diff': 70,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2015-09-05 00:00:00')},
#  {'huc': 'Chair Draft-Calfpasture River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 1582.029599609375,
#   'stdev': 39.77473569502851,
#   'avg': 58.434375,
#   'max': 145.7,
#   'min': 26.3,
#   'max_time_diff': 70,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2015-09-05 00:00:00')},
#  {'huc': 'Chair Draft-Calfpasture River',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 65.9,
#   'max': 65.9,
#   'min': 65.9,
#   'max_time_diff': 70,
#   'max_date': Timestamp('2020-02-02 00:00:00'),
#   'min_date': Timestamp('2015-09-05 00:00:00')},
#  {'huc': 'Buck Creek-Rockfish River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 6.356855955678671,
#   'stdev': 2.521280618193594,
#   'avg': 32.98421052631579,
#   'max': 37.1,
#   'min': 27.6,
#   'max_time_diff': 42,
#   'max_date': Timestamp('2020-01-30 00:00:00'),
#   'min_date': Timestamp('2016-08-06 00:00:00')},
#  {'huc': 'Buck Creek-Rockfish River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 16.13463728733459,
#   'stdev': 4.0167944044143695,
#   'avg': 31.585869565217386,
#   'max': 39.5,
#   'min': 23.5,
#   'max_time_diff': 42,
#   'max_date': Timestamp('2020-01-30 00:00:00'),
#   'min_date': Timestamp('2016-08-06 00:00:00')},
#  {'huc': 'Buck Creek-Rockfish River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 69.6456708958093,
#   'stdev': 8.345398186773913,
#   'avg': 31.84607843137255,
#   'max': 53.95,
#   'min': 17.3,
#   'max_time_diff': 42,
#   'max_date': Timestamp('2020-01-30 00:00:00'),
#   'min_date': Timestamp('2016-08-06 00:00:00')},
#  {'huc': 'Buck Creek-Rockfish River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 50.179251840000006,
#   'stdev': 7.08373149124104,
#   'avg': 30.0204,
#   'max': 46.6,
#   'min': 15.5,
#   'max_time_diff': 42,
#   'max_date': Timestamp('2020-01-30 00:00:00'),
#   'min_date': Timestamp('2016-08-06 00:00:00')},
#  {'huc': 'Buck Creek-Rockfish River',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 53.2384,
#   'stdev': 7.296464897469185,
#   'avg': 24.160000000000004,
#   'max': 29.6,
#   'min': 10.0,
#   'max_time_diff': 42,
#   'max_date': Timestamp('2020-01-30 00:00:00'),
#   'min_date': Timestamp('2016-08-06 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 121.7026003826531,
#   'stdev': 11.031890154577008,
#   'avg': 50.721785714285716,
#   'max': 74.05,
#   'min': 33.2,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 127.86572680788899,
#   'stdev': 11.307772849146245,
#   'avg': 48.50405405405406,
#   'max': 74.4,
#   'min': 35.0,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 37.21786694101508,
#   'stdev': 6.10064479715178,
#   'avg': 39.40185185185185,
#   'max': 55.8,
#   'min': 30.55,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Holloway Draft-Calfpasture River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 147.49890266299357,
#   'stdev': 12.144912624757477,
#   'avg': 48.989393939393935,
#   'max': 71.15,
#   'min': 28.4,
#   'max_time_diff': 38,
#   'max_date': Timestamp('2019-11-17 00:00:00'),
#   'min_date': Timestamp('2016-04-03 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 0.0,
#   'stdev': 0.0,
#   'avg': 70.75,
#   'max': 70.75,
#   'min': 70.75,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 475.88506510416664,
#   'stdev': 21.81479005409327,
#   'avg': 84.80624999999999,
#   'max': 132.25,
#   'min': 55.2,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 525.6184756657484,
#   'stdev': 22.926370747803684,
#   'avg': 74.41969696969697,
#   'max': 117.9,
#   'min': 23.9,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 602.0287885802468,
#   'stdev': 24.5362749532248,
#   'avg': 64.63055555555556,
#   'max': 156.85,
#   'min': 28.5,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Trout Creek-Craig Creek',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 11.787222222222207,
#   'stdev': 3.4332524262311686,
#   'avg': 54.28333333333333,
#   'max': 59.05,
#   'min': 51.1,
#   'max_time_diff': 49,
#   'max_date': Timestamp('2020-01-19 00:00:00'),
#   'min_date': Timestamp('2016-12-23 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 1417.010222222222,
#   'stdev': 37.64319622750202,
#   'avg': 231.56666666666666,
#   'max': 284.5,
#   'min': 163.9,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 1671.173875,
#   'stdev': 40.879993578766616,
#   'avg': 228.475,
#   'max': 296.0,
#   'min': 151.4,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 1586.9541493055556,
#   'stdev': 39.83659309360623,
#   'avg': 198.44583333333333,
#   'max': 262.0,
#   'min': 103.5,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 1938.0213760000001,
#   'stdev': 44.022964189159275,
#   'avg': 223.368,
#   'max': 287.0,
#   'min': 134.1,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Bolar Run-Jackson River',
#   'quarter': 'Q1 2020',
#   'q': 'Q1',
#   'year': '2020',
#   'var': 16.402499999999975,
#   'stdev': 4.049999999999997,
#   'avg': 185.85000000000002,
#   'max': 189.9,
#   'min': 181.8,
#   'max_time_diff': 64,
#   'max_date': Timestamp('2020-01-28 00:00:00'),
#   'min_date': Timestamp('2016-04-11 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q1 2016',
#   'q': 'Q1',
#   'year': '2016',
#   'var': 8.311487603305785,
#   'stdev': 2.8829650714682247,
#   'avg': 37.11818181818182,
#   'max': 42.2,
#   'min': 33.25,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q1 2017',
#   'q': 'Q1',
#   'year': '2017',
#   'var': 119.52657171201814,
#   'stdev': 10.932820848802844,
#   'avg': 41.50595238095238,
#   'max': 97.9,
#   'min': 30.6,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q1 2018',
#   'q': 'Q1',
#   'year': '2018',
#   'var': 23.251874609375,
#   'stdev': 4.8220197645151766,
#   'avg': 35.981875,
#   'max': 50.0,
#   'min': 26.4,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')},
#  {'huc': 'Dutch Creek-Rockfish River',
#   'quarter': 'Q1 2019',
#   'q': 'Q1',
#   'year': '2019',
#   'var': 34.253960489795915,
#   'stdev': 5.852688313057164,
#   'avg': 34.262285714285724,
#   'max': 49.8,
#   'min': 25.9,
#   'max_time_diff': 44,
#   'max_date': Timestamp('2019-11-29 00:00:00'),
#   'min_date': Timestamp('2016-08-15 00:00:00')}]

# %%
ph_results_df = pd.DataFrame(ph_results)
ph_results_df.head()
# Out:
#                            huc  quarter   q  year       var     stdev  \
# 0  Muddy Run-Susquehanna River  Q2 2015  Q2  2015  0.000000  0.000000
# 1  Muddy Run-Susquehanna River  Q3 2015  Q3  2015  0.645000  0.803119
# 2  Muddy Run-Susquehanna River  Q4 2015  Q4  2015  0.030625  0.175000
# 3  Muddy Run-Susquehanna River  Q1 2016  Q1  2016  0.105089  0.324174
# 4  Muddy Run-Susquehanna River  Q2 2016  Q2  2016  0.005956  0.077172
#
#         avg   max   min  max_time_diff   max_date   min_date
# 0  6.550000  6.55  6.55             91 2019-07-10 2015-05-09
# 1  8.580000  9.63  7.68             91 2019-07-10 2015-05-09
# 2  7.995000  8.17  7.82             91 2019-07-10 2015-05-09
# 3  7.943333  8.40  7.68             91 2019-07-10 2015-05-09
# 4  7.876667  7.95  7.77             91 2019-07-10 2015-05-09

# %%
conductivity_results_df = pd.DataFrame(conductivity_results)
conductivity_results_df.head()
# Out:
#                            huc  quarter   q  year          var      stdev  \
# 0  Muddy Run-Susquehanna River  Q1 2015  Q1  2015   962.805556  31.029108
# 1  Muddy Run-Susquehanna River  Q1 2016  Q1  2016   208.883056  14.452787
# 2  Muddy Run-Susquehanna River  Q1 2017  Q1  2017  1060.148760  32.559926
# 3  Muddy Run-Susquehanna River  Q1 2018  Q1  2018  1606.355047  40.079359
# 4  Muddy Run-Susquehanna River  Q1 2019  Q1  2019   777.696400  27.887209
#
#           avg    max    min  max_time_diff   max_date   min_date
# 0  268.833333  318.0  228.0             91 2019-07-10 2015-05-09
# 1  220.883333  244.0  193.6             91 2019-07-10 2015-05-09
# 2  240.181818  291.0  179.0             91 2019-07-10 2015-05-09
# 3  234.613043  295.0  158.1             91 2019-07-10 2015-05-09
# 4  222.140000  275.0  185.0             91 2019-07-10 2015-05-09

# %%
print(results_df['q'].unique())
# Out:
# ['Q1' 'Q2' 'Q3' 'Q4']

# %%
results_df.to_csv('../SourceMaterial/Measures/Results/water_result.csv')
ph_results_df.to_csv('../SourceMaterial/Measures/Results/ph_result.csv')
conductivity_results_df.to_csv('../SourceMaterial/Measures/Results/conductivity_result.csv')

# %%
print(ph_results_df['q'].unique())
# Out:
# ['Q2' 'Q3' 'Q4' 'Q1']

# %%
print(conductivity_results_df['q'].unique())
# Out:
# ['Q1']
